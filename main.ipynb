# %% [markdown]
# <center><h1>Video Game Sales EDA</h1></center>
#
# ## Introduction
#
# This notebook is an EDA about a video game sales dataset. The main goals of this EDA are to explore which features seem to drive sales, and forecast sales revenues five years past the last year in the dataset. This is a hypothetical marketing data analysis workflow for a fictional indie games studio. According to the problem definition, the studio isn't well established, and as such forecasting should be limited to typical games, and not blockbusters. This EDA is divided into four parts:
#
# - Part 1: Data Preparation - preparing the dataset to be used in the analysis.
# - Part 2: Structural EDA - understanding the structure of the dataset.
# - Part 3: Feature-Level Analysis - analyzing the distributions and relationships of features.
# - Part 4: Feature engineering, modeling, and forecasting - transforming features to improve their usefulness in modeling, and forecasting revenues.

# %% [markdown]
# ### Dataset overview
#
# The dataset being used is about sales of video games across different regions. It was taken from [Video Games Sales](https://www.kaggle.com/datasets/lamskdna/video-games-sales), which was posted by Prithu Verma.
# Quoting from the Kaggle page: "This dataset provides a detailed view of video game sales performance, critical reception, and developer/publisher data across multiple gaming platforms. It’s perfect for exploring how factors like genre, publisher reputation, and critic scores influence global sales - and for building predictive models in data science and machine learning."

# %% [markdown]
# ### Tasks
#
# - Understand the structure of dataset and explore features.
# - Find out which features seem to drive sales.
# - Forecast expected regional revenues of typical games.

# %% [markdown]
# ## Part 1: Data preparations
#
# In this part the environment is configured, and the dataset is imported, examined, and standardized.

# %% [markdown]
# ### Configure the environment

# %%
import warnings
import os

# Suppress all warnings for this process and all child processes
warnings.filterwarnings("ignore")
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
import os
import sys
import subprocess
import requests
from pathlib import Path

PYPROJECT_URL = "https://raw.githubusercontent.com/SomeoneSomewhereelse/eda-video-game-sales/refs/heads/main/pyproject.toml"


def maybe_download(filename: str, url: str) -> None:
    """Helper to download a file if it doesn't exist locally."""
    if not os.path.exists(filename):
        print(f"Downloading {filename}...")
        r = requests.get(url)
        with open(filename, "wb") as f:
            f.write(r.content)
        print("Download finished!")


def setup_environment() -> None:
    # Detect environment
    is_colab = "google.colab" in sys.modules
    is_kaggle = "KAGGLE_URL_BASE" in os.environ
    is_cloud = is_colab or is_kaggle

    # Install uv if not present
    try:
        subprocess.run(["uv", "--version"], capture_output=True, check=True)
    except (subprocess.CalledProcessError, FileNotFoundError):
        print("Installing uv...")
        uv_install_script = "https://astral.sh"
        try:
            # Try installing via curl piped to sh
            subprocess.run(f"curl -LsSf {uv_install_script} | sh", shell=True, check=True)
        except subprocess.CalledProcessError:
            # Fallback to wget piped to sh
            subprocess.run(f"wget -qO- {uv_install_script} | sh", shell=True, check=True)

        os.environ["PATH"] += os.pathsep + os.path.expanduser("~/.local/bin")

    # Cloud logic (Colab/Kaggle)
    if is_cloud:
        platform = "Google Colab" if is_colab else "Kaggle"
        print(f"{platform} detected. Fetching pyproject.toml from GitHub...")
        maybe_download("pyproject.toml", PYPROJECT_URL)

        print("Syncing cloud environment via uv...")
        subprocess.run(["uv", "pip", "install", "--system", "-r", "pyproject.toml"], check=True)

    # Local logic
    else:
        print("Local environment detected. Running uv sync...")
        subprocess.run(["uv", "sync"], check=True)

        project_dir = Path.cwd()
        venv_path = project_dir / ".venv"
        is_running_from_venv = str(venv_path) in sys.executable

        kernel_name = project_dir.name.replace(" ", "_")
        display_name = f"uv ({kernel_name})"
        subprocess.run(
            [
                "uv",
                "run",
                "python",
                "-m",
                "ipykernel",
                "install",
                "--user",
                "--name",
                kernel_name,
                "--display-name",
                display_name,
            ],
            check=True,
        )

        if not is_running_from_venv:
            print("\n" + "!" * 60)
            print(f'ACTION: Switch Kernel to "{display_name}"')
            print("!" * 60)
        else:
            print(f'Active Kernel: "{display_name}"')


setup_environment()

# %%
# Import all modules used by this notebook

# String processing using Regular Expressions
import re

# Memory string buffers
from io import StringIO

# Iterations tools
from itertools import batched, permutations

# Date & time
from datetime import date

# Array operstions
import numpy as np

# Statistics
from scipy import stats

# Dataset interaction
import polars as pl
import polars.selectors as cs

# String similarity and clustering
from sparse_dot_topn import sp_matmul_topn
import networkx as nx

# Data visualization
import plotly.io as pio
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# String encoding & decoding
import chardet
import ftfy


# Modeling and feature processing
# Regression models
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import Ridge, HuberRegressor
from sklearn.tree import DecisionTreeRegressor, export_text
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor

# Textual feature extraction
from sklearn.feature_extraction.text import TfidfVectorizer

# Preprocessing
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler, OrdinalEncoder
from sklearn.pipeline import Pipeline

# Performance metrics
from sklearn.metrics import root_mean_squared_error, mean_absolute_percentage_error
from sklearn.inspection import permutation_importance

# Model tuning
from sklearn.model_selection import ParameterGrid


# HTML parser for inline table text alignment
from html.parser import HTMLParser

# HTML tables
from IPython.display import HTML, display as _display

# Common class methods generation
from dataclasses import dataclass

# Type annotation
from collections.abc import Callable, Iterable
from typing import Literal

# Define IntoExpr type alias
type IntoExpr = pl._typing.IntoExpr | Iterable[pl._typing.IntoExpr]

# %%
# Global configuration

# Global Polars output settings
pl.Config.set_float_precision(4)
pl.Config.set_fmt_str_lengths(200)
pl.Config.set_tbl_cols(-1)
pl.Config.set_tbl_width_chars(-1)

# Dark / light theme
DARK_MODE = True
base_template = "plotly_dark" if DARK_MODE else "plotly_white"

# Custom template inheriting from base template
custom_template = pio.templates[base_template]

# Sequential palette for categorical metrics
custom_template.layout.colorway = px.colors.qualitative.Safe
cat_colors = custom_template.layout.colorway

# Discrete palette for continuous metrics
custom_template.layout.colorscale.sequential = px.colors.sequential.Cividis
cont_colors = custom_template.layout.colorscale.sequential

# Apply theme and palettes globally
pio.templates.default = custom_template
pio.templates["custom_theme"] = custom_template

# %%
# Helper functions & extensions


@pl.api.register_dataframe_namespace("eda")
class EdaDf:
    """
    Helper class for EDA - DataFrame.
    """

    def __init__(self, df: pl.DataFrame) -> None:
        self._df = df

    def to_names(self, obj: IntoExpr) -> list[str]:
        return self._df.lazy().select(obj).collect_schema().names()

    def to_expr(self, obj: IntoExpr) -> pl.Expr:
        return pl.col(self.to_names(obj))

    def columns_by_pred(self, pred: IntoExpr) -> list[str]:
        """
        Get name of columns that satisfy a predicate.
        """

        mask = self._df.select(pred)
        return [col for col in mask.columns if mask[col].any()]

    def describe(self, quantiles: list[float] = [0.25, 0.5, 0.75]) -> None:
        """
        Display a short statistical summary.
        """

        # Generate a summary table for numerical columns
        cols = cs.numeric()

        if len(self.to_names(cols)) > 0:
            numeric_df = self._df.select(
                pl.lit(self.to_names(cols)).alias("column"),
                pl.concat_list(cols.count()).alias("count"),
                pl.concat_list(cols.null_count()).alias("null_count"),
                pl.concat_list(cols.count() / self._df.height).alias("availability"),
                pl.concat_list(cols.mean()).alias("mean"),
                pl.concat_list(cols.std()).alias("std"),
                pl.concat_list(cols.min()).alias("min"),
                *[
                    pl.concat_list(cols.quantile(q)).alias(f"{q * 100:.0f}%")
                    for q in set(quantiles)
                ],
                pl.concat_list(cols.max()).alias("max"),
            ).explode(pl.all())

            with pl.Config(set_tbl_rows=-1):
                display(numeric_df)

        # Generate a summary table for non-numerical columns
        cols = cs.exclude(cs.numeric())

        if len(self.to_names(cols)) > 0:
            non_numeric_df = (
                self._df.select(
                    pl.lit(self.to_names(cols)).alias("column"),
                    pl.concat_list(cols.count()).alias("count"),
                    pl.concat_list(cols.null_count()).alias("null_count"),
                    pl.concat_list(cols.count() / self._df.height).alias("availability"),
                    pl.concat_list(cols.n_unique()).alias("unique"),
                    pl.concat_list(
                        cols.drop_nulls()
                        .value_counts(sort=True)
                        .first()
                        .struct.rename_fields(["top", "freq"])
                    ).alias("top_freq"),
                )
                .explode(pl.all())
                .select(
                    cs.exclude("top_freq"),
                    pl.col("top_freq").struct.unnest(),
                )
            )

            with pl.Config(set_tbl_rows=-1):
                display(non_numeric_df)

    def display_non_ascii(self) -> None:
        """
        Display strings in columns containing non-ASCII characters.
        """

        non_ascii_df = self._df.select(
            cs.string().filter(cs.string().str.contains(r"[^\p{Ascii}]")).drop_nulls().implode()
        )

        cols = non_ascii_df.eda.columns_by_pred(pl.all().list.len() > 0)

        # Display a short list of non-ASCII values per column
        for col in cols:
            # Drop duplicates and sort for reproducibility
            display(non_ascii_df.select(pl.col(col).explode().unique().sort()))

    def display_groups_by_first_word(self, column: str, threshold: int = 300) -> None:
        """
        Group and display strings by first word of normalized strings.
        """
        col = pl.col(column)

        expr = pl.col("norm").str.split(" ")

        result = (
            self._df.with_columns(
                # Normalize values
                col.str.to_lowercase().str.strip_chars().alias("norm"),
            )
            .with_columns(
                # Take the first word of each normalized string
                expr.list.first().alias("first_word"),
                # Keep track of count of words
                expr.list.len().alias("word_count"),
            )
            # Keep string containing more than one word
            .filter(pl.col("word_count") >= 1)
            # Group by first word
            .group_by("first_word")
            # Aggregate unique values and count of elements in each group
            .agg(col.unique().sort().alias("entities"), pl.len().alias("count"))
            # Filter out groups named "the" or with element counts below threshold
            .filter(
                pl.col("count") >= threshold,
                pl.col("first_word") != "the",
            )
            .sort("count", descending=True)
            .select(pl.lit(column).alias("column"), pl.all())
        )

        display(result)

    def collisions_fuzzy(
        self,
        column: str,
        mode: Literal["entity", "title"],
        threshold: float = 0.95,
        top_n: int = 10,
    ) -> pl.DataFrame:
        """
        Search for string collisions using fuzzy matching.
        """
        col = pl.col(column)

        # Normalized strings
        unique_df = (
            self._df.select(col.drop_nulls().unique())
            .with_columns(col.eda.normalize(mode).alias("norm"))
            .filter(pl.col("norm").str.len_chars() >= 3)
        )

        normalized = unique_df["norm"]
        original = unique_df[column].to_list()

        # Return an empty DataFrame if no multiple unique strings
        if normalized.len() < 2:
            return pl.DataFrame(
                schema={
                    "left": pl.String,
                    "right": pl.String,
                    "score": pl.Float64,
                }
            )

        # Create a 3-gram TF-IDF vectorizer with word boundary padding
        vectorizer = TfidfVectorizer(analyzer="char_wb", ngram_range=(3, 3), min_df=1)
        # Learn and return a sparse matrix of (n_strings, n_features)
        tfidf_matrix = vectorizer.fit_transform(normalized)

        # Sparse cosine similarity - only keep top_n matches per row above threshold
        matches = sp_matmul_topn(
            tfidf_matrix, tfidf_matrix.T, top_n=top_n + 1, threshold=threshold, n_threads=-1
        )

        # Extract non-self pairs from the sparse result
        cx = matches.tocoo()
        rows, cols_idx, scores = cx.row, cx.col, cx.data

        # Filter to upper triangle only (avoids A-B / B-A duplicates, and self-matches)
        mask = rows < cols_idx
        rows, cols_idx, scores = rows[mask], cols_idx[mask], scores[mask]

        # Return an empty DataFrame if no matches
        if len(rows) == 0:
            return pl.DataFrame(
                schema={
                    "left": pl.String,
                    "right": pl.String,
                    "score": pl.Float64,
                }
            )

        # Build and return the collisions DataFrame
        return pl.DataFrame(
            {
                "left": [original[i] for i in rows],
                "right": [original[i] for i in cols_idx],
                "score": scores.clip(0, 1).round(4),
            }
        )

    def collapse_fuzzy(
        self,
        column: str,
        mode: Literal["title", "entity"],
        threshold: float = 0.95,
        top_n: int = 10,
    ) -> pl.DataFrame:
        """
        Collapse string collisions in a column using fuzzy matching.
        """
        collisions_df = self.collisions_fuzzy(column, mode, threshold, top_n)

        if collisions_df.is_empty():
            return pl.DataFrame()

        # Build union-find over collision pairs
        parent: dict[str, str] = {}

        def find(x: str) -> str:
            # Path compression
            while parent.get(x, x) != x:
                parent[x] = parent.get(parent[x], parent[x])  # path halving
                x = parent[x]
            return x

        def union(x: str, y: str) -> None:
            rx, ry = find(x), find(y)
            if rx == ry:
                return
            # Canonical value is the shorter/alphabetically first string
            parent[ry if rx <= ry else rx] = rx if rx <= ry else ry

        for left, right in collisions_df.select("left", "right").iter_rows():
            union(left, right)

        # Build collapse mapping: collapses every string to its canonical root
        all_strings = set(collisions_df["left"]).union(collisions_df["right"])
        collapse_map = {s: find(s) for s in all_strings}

        # Apply mapping and return
        return self._df.with_columns(pl.col(column).replace(collapse_map))

    def franchise_fuzzy(self, threshold: float = 0.80) -> pl.DataFrame:
        """
        Extract franchise groupings using fuzzy clustering.
        """

        pat_sequel = r"\s+(vol\s+\d+|chapter\s+\d+|part\s+\d+|\d+|[ivxldcm]+)$"
        pat_subtitle = r"\s*(?::|-+)\s*.+$"
        min_chars = 3

        # Normalize: strip subtitles and sequels to get a comparable base
        df = self._df.with_columns(
            pl.col("title").str.replace(pat_subtitle, "").alias("_title_prefix"),
            pl.coalesce("publisher", "developer", pl.lit("unknown")).alias("_grouper"),
        ).with_columns(
            pl.col("_title_prefix")
            .eda.normalize("title")
            .str.replace(pat_sequel, "")
            .str.strip_chars()
            .alias("_base_title")
        )

        # Fuzzy cluster within each publisher / developer group
        unique_pairs = (
            df.select("_base_title", "_grouper")
            .filter(pl.col("_base_title").str.len_chars() >= min_chars)
            .unique()
        )

        merge_map: dict[str, str] = {}

        for (grouper,), group in unique_pairs.group_by("_grouper"):
            titles = group["_base_title"].to_list()

            if len(titles) < 2:
                continue

            vectorizer = TfidfVectorizer(analyzer="char_wb", ngram_range=(3, 3), min_df=1)
            tfidf = vectorizer.fit_transform(titles)

            matches = sp_matmul_topn(
                tfidf,
                tfidf.T,
                top_n=len(titles),
                threshold=threshold,
                n_threads=-1,
            )

            cx = matches.tocoo()
            mask = cx.row < cx.col
            edges = list(zip(cx.row[mask], cx.col[mask]))

            if not edges:
                continue

            # Connected components: clusters
            G = nx.Graph()
            G.add_nodes_from(range(len(titles)))
            G.add_edges_from(edges)

            for component in nx.connected_components(G):
                members = [titles[i] for i in component]
                # Canonical: shortest string (most likely the base game)
                canonical = min(members, key=len)
                for member in members:
                    if member != canonical:
                        merge_map[f"{member}__{grouper}"] = canonical

        # Apply merge map to derive franchise_base
        df = df.with_columns(
            (pl.col("_base_title") + "__" + pl.col("_grouper")).alias("_lookup_key")
        ).with_columns(
            pl.col("_lookup_key")
            .replace(merge_map)  # merged: canonical base title
            .str.split("__")
            .list.first()  # strip the pub suffix back off
            .alias("_franchise_title_group")
        )

        # franchise_base: canonical group + publisher (stable internal key)
        df = df.with_columns(
            (pl.col("_franchise_title_group") + "_" + pl.col("_grouper")).alias("franchise_base")
        )

        # Derive name and debut date per franchise
        franchise_agg_df = (
            df.sort("release_date", nulls_last=True)
            .group_by("franchise_base")
            .agg(
                # Shortest title in franchise: most likely the root game
                pl.col("_title_prefix")
                .sort_by(pl.col("_title_prefix").str.len_chars())
                .first()
                .alias("franchise_name"),
                pl.col("release_date").min().alias("franchise_debut"),
            )
        )

        # Join aggregates back and return
        return df.join(franchise_agg_df, on="franchise_base", how="left").drop(
            "_title_prefix", "_base_title", "_grouper", "_lookup_key", "_franchise_title_group"
        )

    def corr(self, method: str = "pearson", label: str | None = None) -> pl.DataFrame:
        """Generate a correlation matrix of all numerical column pairs."""
        cols = self.to_names(cs.numeric())
        corrs = []
        for c1 in cols:
            row_exprs = [pl.corr(c1, c2, method=method).alias(c2) for c2 in cols]
            row_data = self._df.select(row_exprs)
            corrs.append(row_data)

        matrix = pl.concat(corrs)
        if label is not None:
            matrix = matrix.with_columns(pl.Series(cols).alias(label)).select([label] + cols)
        return matrix


@pl.api.register_expr_namespace("eda")
class EdaExpr:
    """Helper class for common expressions."""

    def __init__(self, expr: pl.Expr) -> None:
        self._expr = expr

    def normalize(self, mode: Literal["entity", "title"]) -> pl.Expr:
        """
        Normalize strings by converting to lowercase and striping whitespace, panctuation, and (optionally) legal suffixes.
        """
        expr = self._expr.str.to_lowercase()

        if mode == "entity":
            # Aggressive - strip punctuation and legal suffixes
            pat_legal = r"\b(inc|ltd|llc|corp|gmbh|co|sa|pty|plc|holding|production|entertainment|studio|interactive|game)s?\b"
            expr = expr.str.replace_all(r"[^\w\s]", " ").str.replace_all(pat_legal, " ")
        elif mode == "title":
            # Conservative - only normalize whitespace and obvious noise
            # Preserve successive punctuation as distinguishing signal
            expr = expr.str.replace_all(r"[^\w\s+]{2,}", " successive ").str.replace_all(
                r"[^\w\s+]", " "
            )

        return expr.str.replace_all(r"\s+", " ").str.strip_chars()

    def bayesian_smooth(
        self,
        count: str | pl.Expr,
        global_metric: int | float | pl.Series,
        alpha: float,
        is_rate: bool = True,
    ) -> pl.Expr:
        """
        Smooth values by performing Bayesian-Shrinkage toward a global metric.
        """
        if isinstance(count, str):
            count = pl.col(count)

        total = self._expr * count if is_rate else self._expr
        return (total + (global_metric * alpha)) / (count + alpha)

    def gini(self) -> pl.Expr:
        """
        Calculate the Gini coefficient of an expression, which is a number in the range of 0 (equality) and 1 (inequality).
        """

        # Prepare data (drop nulls and handle negative shift)
        x = self._expr.drop_nulls()
        min_val = x.min()
        x = pl.when(min_val < 0).then(x - min_val).otherwise(x)

        # Sort values
        x_sorted = x.sort()
        n = x_sorted.count()

        # Calculate Gini coefficient
        i = pl.int_range(1, n + 1, eager=False)
        numerator = 2 * (i * x_sorted).sum()
        denominator = n * x_sorted.sum()

        return (numerator / denominator) - ((n + 1) / n)


def get_transformed_ticks(
    min_val: int | float,
    max_val: int | float,
    scale: Callable[[np.ndarray], np.ndarray] = np.log10,
    steps: list = [1, 2, 5],
) -> dict[str, float]:
    """
    Generate scaled ticks based on linear min / max values.
    Returns a dict: {label: transformed_position}
    """

    # Start at the nearest power of 10 below min_val
    # Use 1e-9 to avoid log10(0) if min_val is 0
    mag = 10 ** np.floor(np.log10(max(1e-9, min_val)))
    ticks = {}

    while mag <= max_val:
        for s in steps:
            val = mag * s
            if min_val <= val <= max_val:
                ticks[f"{val:g}"] = scale(val)
        mag *= 10
    return ticks


def fix_encoding(filename: str) -> StringIO:
    """
    Fix the encoding of the dataset file from Mac-Roman to UTF-8.
    """
    with open(filename, encoding="UTF-8-SIG") as f:
        text = f.read()

    fixed = text.encode("macroman").decode("utf-8")
    output = StringIO()
    output.write(fixed)
    output.seek(0)

    return output


class AlignmentInliner(HTMLParser):
    def __init__(self, alignments):
        super().__init__()
        self.alignments = alignments
        self.result = []
        self.col_index = 0
        self.in_row = False

    def handle_starttag(self, tag, attrs):
        attrs_dict = dict(attrs)

        # Reset column counter at the start of every row
        if tag == "tr":
            self.in_row = True
            self.col_index = 0

        # Apply alignment to table headers (th) and data cells (td)
        elif tag in ("td", "th") and self.in_row:
            if self.col_index < len(self.alignments):
                align = self.alignments[self.col_index]
                # Append or update the style attribute
                if "style" in attrs_dict:
                    attrs_dict["style"] += f"; text-align: {align};"
                else:
                    attrs_dict["style"] = f"text-align: {align};"
            self.col_index += 1

        # Reconstruct the opening tag
        attr_str = "".join(f' {k}="{v}"' for k, v in attrs_dict.items())
        self.result.append(f"<{tag}{attr_str}>")

    def handle_endtag(self, tag):
        if tag == "tr":
            self.in_row = False
        self.result.append(f"</{tag}>")

    def handle_data(self, data):
        self.result.append(data)

    def get_html(self):
        return "".join(self.result)


def display(obj: pl.DataFrame | pl.Series) -> None:
    """
    Display a Polars DataFrame or Series with auto-text alignment.
    """
    # Determine alignments based on data types
    dtypes = obj.dtypes if hasattr(obj, "dtypes") else [obj.dtype]
    alignments = ["right" if dt.is_numeric() else "left" for dt in dtypes]

    raw_html = obj._repr_html_()

    # Parse HTML and inject inline styles
    parser = AlignmentInliner(alignments)
    parser.feed(raw_html)
    fixed_html = parser.get_html()

    _display(HTML(fixed_html))

# %% [markdown]
# ### Import the dataset

# %%
CSV_URL = "https://raw.githubusercontent.com/SomeoneSomewhereelse/eda-video-game-sales/refs/heads/main/VideoGames_Sales.csv"
CSV_FILE = "VideoGames_Sales.csv"

# Download the dataset file if it doesn't already exist locally
maybe_download(CSV_FILE, CSV_URL)

# %%
# Detect dataset file encoding
with open(CSV_FILE, "rb") as f:
    print(chardet.detect(f.read()))

# %%
# Load the dataset and store it in a DataFrame object called df
df = pl.read_csv(CSV_FILE, encoding="UTF-8-SIG")

# Display the first 5 rows
display(df.head(5))

# %% [markdown]
# A short overview of the columns in the dataset. Quoting from the Kaggle page:
# |Feature|Description|
# |---|---|
# |title|Name of the video game|
# |console|Platform or console on which the game was released (e.g., PS4, X360, PC)|
# |genre|Game genre (e.g., Action, Shooter, Sports)|
# |publisher|Publishing company responsible for releasing the game|
# |developer|Game development studio|
# |critic_score|Average critic rating (scale of 1-10)|
# |total_sales(mil)|Total worldwide sales in millions of units|
# |na_sales(mil)|Sales in North America (millions)|
# |jp_sales(mil)|Sales in Japan (millions)|
# |pal_sales(mil)|Sales in PAL regions (Europe, Australia, etc.) (millions)|
# |other_sales(mil)|Sales in other regions (millions)|
# |release_date|Official release date of the game|

# %% [markdown]
# ### Examine the dataset

# %%
# Print the shape of the dataset
print(f"There are {df.height} rows and {df.width} columns in the dataset")

# %%
# Display columns schema
schema_df = pl.DataFrame({"column": df.schema.keys(), "dtype": df.schema.values()})
with pl.Config(set_tbl_rows=-1):
    display(schema_df)

# %%
# Display number of missing values

null_count = "null_count"

null_count_df = (
    df.null_count()
    .transpose(include_header=True, header_name="column", column_names=[null_count])
    .sort(null_count, descending=True)
)

with pl.Config(set_tbl_rows=-1):
    display(null_count_df)

# %%
# Print the number of duplicated rows
print("Number of full duplicates:", df.is_duplicated().sum())

# %%
# Define columns that constitute a unique game entry
identity = ["title", "console", "publisher", "developer"]

# Find duplicates based on identity
dups = df.filter(df.select(identity).is_duplicated()).sort(identity)

print("Partial duplicates:")
with pl.Config(set_tbl_rows=20):
    display(dups)

# %%
# Display a short statistical summary
df.eda.describe()

# %%
# Examine string columns to detect encoding artifacts
df.eda.display_non_ascii()

# %% [markdown]
# #### Observations
#
# - There are 64016 rows and 12 columns in the dataset.
# - Sales column names contain leading and trailing whitespace characters, and their data type is _string_ instead of _float_.
# - There are 42 duplicated rows.
# - There are at least 206 identity duplicates in the dataset.
# - The dataset contains fragmented observations, where near identical entries cover different regional sales.
# - Multiple near identical entries (e.g., Yu-Gi-Oh! Dungeon Dice Monsters) have mismatching genres (e.g., Misc and Strategy).
# - The data type of the `release_date` column is _string_ instead of _date_.
# - Sales and `critic_score` columns contain many missing values.
# - Sales columns contain invalid numerical values (e.g., $-).
# - `publisher` and `developer` have missing values labeled as _Unknown_.
# - `title`, `publisher`, and `developer` contain non-normalized string values.

# %% [markdown]
# ### Normalize and standardize the dataset

# %%
# Declare globals

TOTAL_SALES_COL = "total_sales_mil"

REGIONAL_SALES_COLS = [
    "na_sales_mil",
    "jp_sales_mil",
    "pal_sales_mil",
    "other_sales_mil",
]

SALES_COLS = [TOTAL_SALES_COL] + REGIONAL_SALES_COLS

# Prettified column names
COL_LABELS = {
    "title": "Title",
    "console": "Console",
    "genre": "Genre",
    "publisher": "Publisher",
    "developer": "Developer",
    "critic_score": "Critic Score",
    "total_sales_mil": "Total",
    "na_sales_mil": "North America",
    "jp_sales_mil": "Japan",
    "pal_sales_mil": "PAL",
    "other_sales_mil": "Other",
    "release_date": "Release Date",
}

SALES_COL_LABELS = [COL_LABELS[c] for c in SALES_COLS]

# %%
# Normalize column names
df = df.rename(lambda c: c.strip().replace("(mil)", "_mil"))

# Verify column names
schema_df = pl.DataFrame({"column": df.schema.keys()})
with pl.Config(set_tbl_rows=-1):
    display(schema_df)

# %%
# Remove duplicates

# Drop duplicated rows and maintain order for reproducibility
df = df.unique(maintain_order=True)

# Verify new shape
print("Number of full duplicates:", df.is_duplicated().sum())

# %%
# Examine invalid numerical values in sales columns

cols = pl.col(SALES_COLS)

sales = df.select(
    # Strip whitespace and $ characters, convert to float, and filter out valid numerical values
    cols.filter(cols.str.strip_chars("$ ").cast(pl.Float64, strict=False).is_null()).implode()
)

for col in sales.iter_columns():
    # Inspect invalid numerical values
    items = col.item().unique().to_list()
    print(f"{col.name}:", items)

# %%
# The values above aren't valid numerical values

# Convert sales to float and coerce invalid numerical values to null
df = df.with_columns(pl.col(SALES_COLS).str.strip_chars("$ ").cast(pl.Float64, strict=False))

# Verify sales data types
sales_df = df.select(pl.col(SALES_COLS))
schema_df = pl.DataFrame({"column": sales_df.schema.keys(), "dtype": sales_df.schema.values()})
with pl.Config(set_tbl_rows=-1):
    display(schema_df)

# %%
# Detect the encoding used by strings which contain non-ASCII characters

garbled_string = "1000 Cooking Recipes from ELLE √† table"

result = ftfy.fix_and_explain(garbled_string)
print(result.explanation)

# %%
# Fix common encoding artifacts and remove superfluous whitespace characters

cols = pl.col(["title", "publisher", "developer"])

df = df.with_columns(
    cols.map_elements(lambda x: x.encode("macroman").decode("utf-8"))
).with_columns(cols.str.replace_all(r"\s+", " "))

# Verify encoding
df.eda.display_non_ascii()

# %%
# Replace Unknown with null

cols = ["publisher", "developer"]

df = df.with_columns(pl.col(cols).replace("Unknown", None))

# Verify
df.select(cols).eda.describe()

# %% [markdown]
# ### Initial cleaning pipeline

# %%
# Create a function to load and minimally clean the dataset


def load_dataset() -> pl.DataFrame:
    """
    Load, standardize, and minimally clean the dataset.
    """
    title = "title"
    release_date = "release_date"
    cols = pl.col([title, "publisher", "developer"])

    # Fix Mac-Roman encoding
    fixed = fix_encoding(CSV_FILE)

    return (
        # Lazily scan the dataset
        pl.scan_csv(fixed)
        # Strip and normalize column names
        .rename(lambda c: c.strip().replace("(mil)", "_mil"))
        .with_columns(
            # Parse dates
            pl.col(release_date).str.to_date("%m/%d/%Y"),
            # Convert sales columns to float
            pl.col(SALES_COLS).str.strip_chars("$ ").cast(pl.Float64, strict=False),
        )
        .with_columns(
            # Remove superfluous whitespace characters
            cols.str.replace_all(r"\s+", " ")
        )
        .with_columns(
            # Replace "Unknown" with null
            cols.exclude(title).replace("Unknown", None)
        )
        # Remove duplicated rows and maintain order for reproducibility
        .unique(maintain_order=True)
        # Collect transformations
        .collect()
    )

# %%
# Load the dataset and verify transformations

df = load_dataset()

schema_df = pl.DataFrame({"column": df.schema.keys(), "dtype": df.schema.values()})
with pl.Config(set_tbl_rows=-1):
    display(schema_df)

print("Number of full duplicates:", df.is_duplicated().sum())
df.eda.display_non_ascii()

# %% [markdown]
# The dataset is now standardized and ready to be explored. Before looking into distributions and relationships, its structure will be examined.

# %% [markdown]
# ## Part 2: Structural EDA
#
# This part is about checking the integrity and validity of the dataset. The main task is to examine features by observing the validity of their values, and the structure of their missingness.

# %% [markdown]
# ### Dataset integrity

# %% [markdown]
# #### Statistical characteristics

# %%
# Display a short statistical summary
df.eda.describe()

# %% [markdown]
# ##### Observations
#
# - All columns appear to contain values within standard ranges.
# - The sales columns are target variables and exhibit an extremely high level of missingness.
# - `critic_score` contains an extremely high level of missingness.
# - `publisher` and `developer` contain very high cardinality and moderate to high levels of missingness.
# - `release_date` contains a moderate level of missingness.
# - `title` contains extremely high cardinality and no missing values.
# - `console` contains moderate to high cardinality and no missing values.
# - `genre` contains low to moderate cardinality and no missing values, as well as a _Misc_ genre that should be examined.

# %% [markdown]
# #### Total and regional sales

# %%
# Compare total and sum of regional sales

total_sales_col = pl.col(TOTAL_SALES_COL)
regional_sales_sum = "regional_sales_sum"

# Get total sales and sum of regional sales for observations containing total sales
sales_df = (
    df.filter(total_sales_col.is_not_null()).select(
        total_sales_col.round(4),
        pl.sum_horizontal(REGIONAL_SALES_COLS).round(4).alias(regional_sales_sum),
    )
    # Filter out rows with no difference
).filter(total_sales_col.sub(pl.col(regional_sales_sum)).abs() > 0)

# Display total sales and sum of regional sales side-by-side
display(sales_df)

# Get counts of unique differences
counts_df = sales_df.select(
    total_sales_col.sub(pl.col(regional_sales_sum))
    .abs()
    .round(4)
    .value_counts(sort=True)
    .struct.rename_fields(["difference", "count"])
    .struct.unnest()
)

display(counts_df)

# %% [markdown]
# #### Game and console release dates

# %%
# Check if there are games released prior to their correpsonding console launch date

# Reference data for console / platform launches
console_data = [
    {"console": "2600", "launch_date": date(1977, 9, 11)},
    {"console": "3DO", "launch_date": date(1993, 10, 4)},
    {"console": "3DS", "launch_date": date(2011, 2, 26)},
    {"console": "5200", "launch_date": date(1982, 11, 1)},
    {"console": "7800", "launch_date": date(1986, 5, 1)},
    {"console": "ACPC", "launch_date": date(1984, 6, 1)},
    {"console": "AJ", "launch_date": date(1993, 11, 23)},
    {"console": "AST", "launch_date": date(1985, 6, 1)},
    {"console": "Aco", "launch_date": date(1983, 8, 25)},
    {"console": "All", "launch_date": None},  # Aggregator
    {"console": "Amig", "launch_date": date(1985, 7, 23)},
    {"console": "And", "launch_date": date(2008, 9, 23)},
    {"console": "ApII", "launch_date": date(1977, 6, 1)},
    {"console": "Arc", "launch_date": date(1971, 11, 1)},
    {"console": "BBCM", "launch_date": date(1981, 12, 1)},
    {"console": "BRW", "launch_date": date(1996, 11, 1)},
    {"console": "C128", "launch_date": date(1985, 1, 1)},
    {"console": "C64", "launch_date": date(1982, 8, 1)},
    {"console": "CD32", "launch_date": date(1993, 9, 17)},
    {"console": "CDi", "launch_date": date(1991, 12, 3)},
    {"console": "CV", "launch_date": date(1982, 8, 1)},
    {"console": "DC", "launch_date": date(1998, 11, 27)},
    {"console": "DS", "launch_date": date(2004, 11, 21)},
    {"console": "DSi", "launch_date": date(2008, 11, 1)},
    {"console": "DSiW", "launch_date": date(2008, 11, 1)},
    {"console": "FDS", "launch_date": date(1986, 2, 21)},
    {"console": "FMT", "launch_date": date(1989, 2, 28)},
    {"console": "GB", "launch_date": date(1989, 4, 21)},
    {"console": "GBA", "launch_date": date(2001, 3, 21)},
    {"console": "GBC", "launch_date": date(1998, 10, 21)},
    {"console": "GC", "launch_date": date(2001, 9, 14)},
    {"console": "GEN", "launch_date": date(1988, 10, 29)},
    {"console": "GG", "launch_date": date(1990, 10, 6)},
    {"console": "GIZ", "launch_date": date(2005, 3, 19)},
    {"console": "Int", "launch_date": date(1979, 1, 1)},
    {"console": "Linux", "launch_date": date(1991, 9, 17)},
    {"console": "Lynx", "launch_date": date(1989, 9, 1)},
    {"console": "MS", "launch_date": date(1985, 10, 20)},
    {"console": "MSD", "launch_date": date(1981, 8, 12)},
    {"console": "MSX", "launch_date": date(1983, 6, 16)},
    {"console": "Mob", "launch_date": date(2000, 1, 1)},
    {"console": "N64", "launch_date": date(1996, 6, 23)},
    {"console": "NES", "launch_date": date(1983, 7, 15)},
    {"console": "NG", "launch_date": date(1990, 4, 26)},
    {"console": "NGage", "launch_date": date(2003, 10, 7)},
    {"console": "NS", "launch_date": date(2017, 3, 3)},
    {"console": "OR", "launch_date": date(2016, 3, 28)},
    {"console": "OSX", "launch_date": date(2001, 3, 24)},
    {"console": "Ouya", "launch_date": date(2013, 6, 25)},
    {"console": "PC", "launch_date": None},  # Aggregator
    {"console": "PCE", "launch_date": date(1987, 10, 30)},
    {"console": "PCFX", "launch_date": date(1994, 12, 23)},
    {"console": "PS", "launch_date": date(1994, 12, 3)},
    {"console": "PS2", "launch_date": date(2000, 3, 4)},
    {"console": "PS3", "launch_date": date(2006, 11, 11)},
    {"console": "PS4", "launch_date": date(2013, 11, 15)},
    {"console": "PS5", "launch_date": date(2020, 11, 12)},
    {"console": "PSN", "launch_date": date(2006, 11, 11)},
    {"console": "PSP", "launch_date": date(2004, 12, 12)},
    {"console": "PSV", "launch_date": date(2011, 12, 17)},
    {"console": "S32X", "launch_date": date(1994, 11, 21)},
    {"console": "SAT", "launch_date": date(1994, 11, 22)},
    {"console": "SCD", "launch_date": date(1991, 12, 12)},
    {"console": "SNES", "launch_date": date(1990, 11, 21)},
    {"console": "Series", "launch_date": None},  # Aggregator
    {"console": "TG16", "launch_date": date(1987, 10, 30)},
    {"console": "VB", "launch_date": date(1995, 7, 21)},
    {"console": "VC", "launch_date": date(2006, 11, 19)},
    {"console": "WS", "launch_date": date(1999, 3, 4)},
    {"console": "WW", "launch_date": date(2008, 3, 25)},
    {"console": "Wii", "launch_date": date(2006, 11, 19)},
    {"console": "WiiU", "launch_date": date(2012, 11, 18)},
    {"console": "WinP", "launch_date": date(2010, 10, 21)},
    {"console": "X360", "launch_date": date(2005, 11, 22)},
    {"console": "XB", "launch_date": date(2001, 11, 15)},
    {"console": "XBL", "launch_date": date(2002, 11, 15)},
    {"console": "XOne", "launch_date": date(2013, 11, 22)},
    {"console": "XS", "launch_date": date(2020, 11, 10)},
    {"console": "ZXS", "launch_date": date(1982, 4, 23)},
    {"console": "iOS", "launch_date": date(2008, 7, 10)},
    {"console": "iQue", "launch_date": date(2003, 11, 17)},
]

launch_date = pl.col("launch_date")
release_date = pl.col("release_date")
console = "console"
is_anomaly = "is_anomaly"

# Create a DataFrame which contains consoles and their launch date
launch_dates_df = pl.DataFrame(console_data).with_columns(launch_date.cast(pl.Date))

# Join dataset with launch dates based on the console column and flag anomalies
anomaly_df = df.join(launch_dates_df, on=console, how="left").with_columns(
    pl.all_horizontal(
        release_date.is_not_null(),
        launch_date.is_not_null(),
        release_date.dt.year() < launch_date.dt.year(),
    ).alias(is_anomaly),
)

display(anomaly_df.filter(pl.col(is_anomaly)))

# %% [markdown]
# #### Spelling and formatting

# %%
# Examine titles containing large counts of words

title = pl.col("title")
words = "words"
count = "count"

# Calculate count of words in titles
word_count_df = df.select(title, title.str.split(" ").alias(words)).with_columns(
    pl.col(words).list.len().alias(count)
)

# Keep titles containing more than 10 "words"
long_titles_df = word_count_df.filter(pl.col(count) > 10).select(
    title.unique().sort().alias("long_titles")
)

display(long_titles_df)

# %%
# Examine string collisions

cols = ["title", "publisher", "developer"]
col_modes = ["title", "entity", "entity"]

for col, mode in zip(cols, col_modes):
    collisions_df = (
        df.eda.collisions_fuzzy(col, mode)
        .sort(["score", "left"], descending=[True, False])
        .select(pl.lit(col).alias("column"), pl.all())
    )
    display(collisions_df)

# %%
# Examine publishers and developers

cols = ["publisher", "developer"]

with pl.Config(
    set_tbl_rows=-1,
    set_fmt_table_cell_list_len=-1,
    set_tbl_width_chars=-1,
    set_fmt_str_lengths=10000,
):
    for col in cols:
        # Display potentially identical publishers and developers
        df.eda.display_groups_by_first_word(col, threshold=1000)

# %% [markdown]
# #### Genre and console categories

# %%
# Examine categories in genre and console

cols = ["genre", "console"]

uniques = df.select(pl.col(cols).unique().sort().implode())

for col in cols:
    print(f"Unique values in {col}:")

    for vals in batched(uniques[col].explode(), 4):
        print(*[f"{vals[i]:>16}" for i in range(len(vals))])

    print()

# %% [markdown]
# #### Genre classifications

# %%
# Examine the genre column and the "Misc" category in particular

title = "title"
genre = "genre"
genre_col = pl.col(genre)

genre_mismatch_df = (
    df.group_by(title)
    .agg(genre)
    # Keep titles which have multiple unique genres
    .filter(genre_col.list.n_unique() > 1)
    .sort(title)
)

# Keep titles which contain the "Misc" category
misc_mismatch_df = genre_mismatch_df.filter(genre_col.list.contains("Misc"))

# Examine genres across the GTA franchise
gta_genres = df.filter(pl.col(title).str.contains("(?i)grand theft auto")).select(
    genre_col.unique().sort()
)

with pl.Config(set_fmt_table_cell_list_len=-1):
    print("Titles with genre mismatches:")
    display(genre_mismatch_df)
    print("\nTitles with genre mismatches (Misc):")
    display(misc_mismatch_df)
    print("\nGenres across GTA games:", gta_genres[genre].to_list())

# %% [markdown]
# #### Observations
#
# - There are insignificant differences between total sales and the sum of regional sales, which are likely caused by rounding artifacts.
# - Multiple observations have a release date earlier than their corresponding consoles' or platforms' launch date.
# - Genres appear to be inconsistently classified between identical games and across games from the same franchise. The _Misc_ genre appears to be a catch-all tag.
# - Titles contain unique games, as well as bundles and series. They also include collisions (e.g., 12 Minutes / 12 minutes) which may normalize to the same canonical form.
# - Publishers and developers contain many normalization collisions that refer to both identical (e.g., 5TH Cell / 5th Cell) and separate (e.g., Imagineer / Imagineering) entities. Additionally, they include brand and business entities (e.g., 2XL Games / 2XL Games, Inc.), subsidiaries, and branches that may be normalized to the same canonical form.
#
# The dataset appears to be fragmented by inconsistent formatting and, as observed in _Part 1_, multiple other inconsistencies and duplications. Using naive fuzzy matching to distinguish between formatting inconsistencies and legitimate related titles (sequels, editions) would not be feasible. Therefore, reflecting on absolute figures would not be advisable; **relative patterns** will be used instead.

# %% [markdown]
# #### Normalize and standardize the dataset

# %%
# Remove games released prior to their corresponding console launch date

console = "console"
release_date = pl.col("release_date")
launch_date = "launch_date"
launch_date_col = pl.col(launch_date)
is_anomaly = "is_anomaly"

# Filter out anomalies
df = (
    df.join(launch_dates_df, on=console, how="left")
    # Filter out releases with incorrect dates
    .filter(
        pl.any_horizontal(
            release_date.is_null(),
            launch_date_col.is_null(),
            release_date.dt.year() >= launch_date_col.dt.year(),
        )
    )
    .drop(launch_date)
)

# Verify
anomaly_df = df.join(launch_dates_df, on=console, how="left").with_columns(
    (
        pl.all_horizontal(
            release_date.is_not_null(),
            launch_date_col.is_not_null(),
            release_date.dt.year() < launch_date_col.dt.year(),
        )
    ).alias(is_anomaly),
)

num_anomalies = anomaly_df[is_anomaly].sum()
print("Number of games with an anomalous release date:", num_anomalies)

# %%
# Collapse identical publishers and developers using mapping

# Publisher and developer mapping for collapsing entities
pub_dev_map = [
    (r"\b505 games\b", "505 Games"),
    (r"\bascii\b", "ASCII"),
    (r"\bactivision\b", "Activision"),
    (r"\batari\b|\binfogrames\b", "Atari"),
    (r"\batlus\b", "Atlus"),
    (r"^avalanche (studios|software|productions)", "Avalanche"),
    (r"\bnamco\b|\bbandai\b", "Bandai Namco"),
    (r"\bbethesda\b", "Bethesda"),
    (r"\bbioware\b", "BioWare"),
    (r"^blitz", "Blitz Games"),
    (r"\bcapcom\b", "Capcom"),
    (r"^climax", "Climax"),
    (r"\bcodemasters\b", "Codemasters"),
    (r"\bcompile\b", "Compile"),
    (r"\bdigital eclipse\b", "Digital Eclipse"),
    (r"\bdigital fusion\b", "Digital Fusion"),
    (r"\bdigital goldfish\b", "Digital Goldfish"),
    (r"\bdigital illusions\b", "Digital Illusions"),
    (r"\bdigital leisure\b", "Digital Leisure"),
    (r"\bdigital dna\b", "DigitalDNA"),
    (r"\bdisney\b", "Disney"),
    (r"\beidos\b", "Eidos"),
    (r"^ea\b|\belectronic arts\b", "Electronic Arts"),
    (r"^from software", "FromSoftware"),
    (r"\bgamemill\b", "Gamemill"),
    (r"\bhudson\b", "Hudson Soft"),
    (r"\bidea factory\b", "Idea Factory"),
    (r"^intelligent (systems|games|design)", "Intelligent Systems"),
    (r"\binterplay\b", "Interplay"),
    (r"^irem", "Irem"),
    (r"^jaleco", "Jaleco"),
    (r"\bkadokawa\b", "Kadokawa"),
    (r"\bkalypso\b", "Kalypso"),
    (r"\bkemco\b", "Kemco"),
    (r"\bkoei\b|\btecmo\b", "Koei Tecmo"),
    (r"\bkonami\b", "Konami"),
    (r"\blucasarts\b", "LucasArts"),
    (r"\bmajesco\b", "Majesco"),
    (r"\bmarvelous\b", "Marvelous"),
    (r"\bmattel\b", "Mattel"),
    (r"\bmicrosoft\b|\bxbox\b", "Microsoft Studios"),
    (r"\bmidway\b", "Midway"),
    (r"^midway", "Midway"),
    (r"\bmilestone\b", "Milestone"),
    (r"\bnec\b", "NEC"),
    (r"\bnatsume\b", "Natsume"),
    (r"\bsega falcom\b", "Nihon Falcom"),
    (r"\bnintendo\b", "Nintendo"),
    (r"\bparadox\b", "Paradox"),
    (r"^probe", "Probe"),
    (r"\brare\b", "Rare"),
    (r"^rebellion", "Rebellion Developments"),
    (r"\brockstar\b", "Rockstar Games"),
    (r"\bsnk\b", "SNK"),
    (r"\bsega\b", "Sega"),
    (r"^sierra", "Sierra"),
    (r"\bsierra\b", "Sierra"),
    (r"\bscee\b|\bsony\b", "Sony"),
    (r"\bsouthpeak\b", "Southpeak"),
    (r"\bspike\b", "Spike Chunsoft"),
    (r"\bsquare\b|\benix\b", "Square Enix"),
    (r"\bthq\b", "THQ"),
    (r"\btaito\b", "Taito"),
    (r"\btakara\b", "Takara Tomy"),
    (r"\b2k\b|\btake[- ]+two\b", "Take-Two"),
    (r"^team17", "Team17"),
    (r"\btraveller\b", "Traveller's Tales"),
    (r"\bubisoft\b", "Ubisoft"),
    (r"^vicarious visions", "Vicarious Visions"),
    (r"\bvirgin\b", "Virgin"),
    (r"\bwarner\b", "Warner Bros."),
    (r"\bwayforward\b", "WayForward Technologies"),
    (r"^yuke'?s", "Yuke's"),
    (r"\bzoo games\b", "Zoo Games"),
]


def apply_mapping(expr: pl.Expr, mapping: list[tuple[str, str]]) -> pl.Expr:
    norm = expr.str.to_lowercase().str.strip_chars()

    # Build result array - start with titlecase fallback
    result = norm.str.to_titlecase()

    # Apply in reverse so first match wins (like when / then)
    for pattern, replacement in reversed(mapping):
        mask = norm.str.contains(pattern)
        result = pl.when(mask).then(pl.lit(replacement)).otherwise(result)

    # Preserve nulls
    return pl.when(expr.is_null()).then(None).otherwise(result)


cols = ["publisher", "developer"]

# Collapse and verify
df = df.with_columns(apply_mapping(pl.col(cols), pub_dev_map).name.keep())


with pl.Config(
    set_tbl_rows=-1,
    set_fmt_table_cell_list_len=-1,
    set_tbl_width_chars=-1,
    set_fmt_str_lengths=10000,
):
    for col in cols:
        df.eda.display_groups_by_first_word(col, threshold=1000)

# %%
# Collapse similar titles, publishers, and developers using fuzzy matching

cols = ["title", "publisher", "developer"]
col_modes = ["title", "entity", "entity"]

# Verify
print("Number of fuzzy collisions:")
for col, mode in zip(cols, col_modes):
    df = df.eda.collapse_fuzzy(col, mode, threshold=0.997)

    collisions_df = df.eda.collisions_fuzzy(col, mode, threshold=0.997)
    print(f"{col:<12}{collisions_df.height}")

# %%
# Re-examine duplicates

# Define columns that constitute a unique game entry
identity = ["title", "console", "publisher", "developer"]

print("Full duplicates:")
display(df.filter(df.is_duplicated()))

dup_df = df.filter(df.select(identity).is_duplicated()).sort(identity)

print("\nPartial duplicates:")
display(dup_df)

# %%
# Deduplicate and merge identical games

release_date, release_year = "release_date", "release_year"
cols = SALES_COLS + [release_date]
identity = ["title", "console", "publisher", "developer"]

base_df = df.with_columns(pl.col(release_date).dt.year().alias(release_year))

dup_df = (
    base_df.filter(base_df.select(identity + [release_year]).is_duplicated())
    # Group identical games within the same release year
    .group_by(identity + [release_year])
    # Aggregate to minimum release date and maximum sales values
    .agg(pl.col(release_date).min(), pl.col(SALES_COLS).max())
)

df = (
    # Join back and merge aggregates to their respective columns
    base_df.join(dup_df, on=identity + [release_year], how="left", suffix="_agg")
    .with_columns([pl.coalesce(pl.col(f"{c}_agg"), pl.col(c)).alias(c) for c in cols])
    # Re-calculate total sales from regional sales
    .with_columns(
        pl.when(pl.all_horizontal(pl.col(REGIONAL_SALES_COLS).is_null()))
        .then(None)
        .otherwise(pl.sum_horizontal(REGIONAL_SALES_COLS))
        .alias(TOTAL_SALES_COL)
    )
    .drop([f"{c}_agg" for c in cols] + [release_year])
    # Deduplicate
    .unique(subset=identity, maintain_order=True)
)

n_full = df.filter(df.is_duplicated()).height
n_partial = df.filter(df.select(identity).is_duplicated()).height

print("Number of full duplicates:", n_full)
print("Number of partial duplicates:", n_partial)

# %%
# Fix genre collisions using priority mapping

# Genre priority mapping from most to least generic - higher values take precedence
genre_map = {
    "Misc": 0,
    "Action": 1,
    "Adventure": 2,
    "Action-Adventure": 3,
    "Party": 4,
    "Sandbox": 5,
    "Shooter": 6,
    "Platform": 7,
    "Racing": 8,
    "Sports": 9,
    "Fighting": 10,
    "Music": 11,
    "Simulation": 12,
    "Role-Playing": 13,
    "MMO": 14,
    "Puzzle": 15,
    "Strategy": 16,
    "Board Game": 17,
    "Visual Novel": 18,
    "Education": 19,
}

title = "title"
genre = "genre"
publisher = "publisher"
priority = "priority"
franchise_base = "franchise_base"
franchise_genre = "franchise_genre"

df = (
    # Map genre to priority
    df.eda.franchise_fuzzy(threshold=0.7).with_columns(
        pl.col(genre).replace_strict(genre_map, default=-1).alias(priority),
    )
)

# Keep the genre with the highest priority across franchise
franchise_genre_df = df.group_by(franchise_base).agg(
    pl.col(genre).sort_by(priority, descending=True).first().alias(franchise_genre)
)

df = (
    # Pass 1: join back and fill if current genre is low-priority
    df.join(franchise_genre_df, on=franchise_base, how="left")
    .with_columns(
        pl.when(pl.col(genre) == "Misc")
        .then(pl.col(franchise_genre))
        .otherwise(pl.col(genre))
        .alias(genre)
    )
    # Pass 2: keep the genre with the highest priority between identical titles
    .with_columns(pl.col(genre).sort_by(priority, descending=True).first().over(title, publisher))
    .with_columns(pl.col(genre).sort_by(priority, descending=True).first().over(title))
    .drop(priority, franchise_base, franchise_genre)
)

# Verify
genre_mismatch_df = df.group_by(title).agg(genre).filter(pl.col(genre).list.n_unique() > 1)
gta_genres = (
    df.filter(pl.col(title).str.contains("(?i)grand theft auto"))
    .select(pl.col(genre).unique().sort())[genre]
    .to_list()
)

print("Number of genre mismatches:", genre_mismatch_df.height)
print("Genres across GTA games:", gta_genres)

# %% [markdown]
# #### Updated cleaning pipeline

# %%
# Create a function to load and moderately clean the dataset

# Reference data for console / platform launches
console_data = [
    {"console": "2600", "launch_date": date(1977, 9, 11)},
    {"console": "3DO", "launch_date": date(1993, 10, 4)},
    {"console": "3DS", "launch_date": date(2011, 2, 26)},
    {"console": "5200", "launch_date": date(1982, 11, 1)},
    {"console": "7800", "launch_date": date(1986, 5, 1)},
    {"console": "ACPC", "launch_date": date(1984, 6, 1)},
    {"console": "AJ", "launch_date": date(1993, 11, 23)},
    {"console": "AST", "launch_date": date(1985, 6, 1)},
    {"console": "Aco", "launch_date": date(1983, 8, 25)},
    {"console": "All", "launch_date": None},  # Aggregator
    {"console": "Amig", "launch_date": date(1985, 7, 23)},
    {"console": "And", "launch_date": date(2008, 9, 23)},
    {"console": "ApII", "launch_date": date(1977, 6, 1)},
    {"console": "Arc", "launch_date": date(1971, 11, 1)},
    {"console": "BBCM", "launch_date": date(1981, 12, 1)},
    {"console": "BRW", "launch_date": date(1996, 11, 1)},
    {"console": "C128", "launch_date": date(1985, 1, 1)},
    {"console": "C64", "launch_date": date(1982, 8, 1)},
    {"console": "CD32", "launch_date": date(1993, 9, 17)},
    {"console": "CDi", "launch_date": date(1991, 12, 3)},
    {"console": "CV", "launch_date": date(1982, 8, 1)},
    {"console": "DC", "launch_date": date(1998, 11, 27)},
    {"console": "DS", "launch_date": date(2004, 11, 21)},
    {"console": "DSi", "launch_date": date(2008, 11, 1)},
    {"console": "DSiW", "launch_date": date(2008, 11, 1)},
    {"console": "FDS", "launch_date": date(1986, 2, 21)},
    {"console": "FMT", "launch_date": date(1989, 2, 28)},
    {"console": "GB", "launch_date": date(1989, 4, 21)},
    {"console": "GBA", "launch_date": date(2001, 3, 21)},
    {"console": "GBC", "launch_date": date(1998, 10, 21)},
    {"console": "GC", "launch_date": date(2001, 9, 14)},
    {"console": "GEN", "launch_date": date(1988, 10, 29)},
    {"console": "GG", "launch_date": date(1990, 10, 6)},
    {"console": "GIZ", "launch_date": date(2005, 3, 19)},
    {"console": "Int", "launch_date": date(1979, 1, 1)},
    {"console": "Linux", "launch_date": date(1991, 9, 17)},
    {"console": "Lynx", "launch_date": date(1989, 9, 1)},
    {"console": "MS", "launch_date": date(1985, 10, 20)},
    {"console": "MSD", "launch_date": date(1981, 8, 12)},
    {"console": "MSX", "launch_date": date(1983, 6, 16)},
    {"console": "Mob", "launch_date": date(2000, 1, 1)},
    {"console": "N64", "launch_date": date(1996, 6, 23)},
    {"console": "NES", "launch_date": date(1983, 7, 15)},
    {"console": "NG", "launch_date": date(1990, 4, 26)},
    {"console": "NGage", "launch_date": date(2003, 10, 7)},
    {"console": "NS", "launch_date": date(2017, 3, 3)},
    {"console": "OR", "launch_date": date(2016, 3, 28)},
    {"console": "OSX", "launch_date": date(2001, 3, 24)},
    {"console": "Ouya", "launch_date": date(2013, 6, 25)},
    {"console": "PC", "launch_date": None},  # Aggregator
    {"console": "PCE", "launch_date": date(1987, 10, 30)},
    {"console": "PCFX", "launch_date": date(1994, 12, 23)},
    {"console": "PS", "launch_date": date(1994, 12, 3)},
    {"console": "PS2", "launch_date": date(2000, 3, 4)},
    {"console": "PS3", "launch_date": date(2006, 11, 11)},
    {"console": "PS4", "launch_date": date(2013, 11, 15)},
    {"console": "PS5", "launch_date": date(2020, 11, 12)},
    {"console": "PSN", "launch_date": date(2006, 11, 11)},
    {"console": "PSP", "launch_date": date(2004, 12, 12)},
    {"console": "PSV", "launch_date": date(2011, 12, 17)},
    {"console": "S32X", "launch_date": date(1994, 11, 21)},
    {"console": "SAT", "launch_date": date(1994, 11, 22)},
    {"console": "SCD", "launch_date": date(1991, 12, 12)},
    {"console": "SNES", "launch_date": date(1990, 11, 21)},
    {"console": "Series", "launch_date": None},  # Aggregator
    {"console": "TG16", "launch_date": date(1987, 10, 30)},
    {"console": "VB", "launch_date": date(1995, 7, 21)},
    {"console": "VC", "launch_date": date(2006, 11, 19)},
    {"console": "WS", "launch_date": date(1999, 3, 4)},
    {"console": "WW", "launch_date": date(2008, 3, 25)},
    {"console": "Wii", "launch_date": date(2006, 11, 19)},
    {"console": "WiiU", "launch_date": date(2012, 11, 18)},
    {"console": "WinP", "launch_date": date(2010, 10, 21)},
    {"console": "X360", "launch_date": date(2005, 11, 22)},
    {"console": "XB", "launch_date": date(2001, 11, 15)},
    {"console": "XBL", "launch_date": date(2002, 11, 15)},
    {"console": "XOne", "launch_date": date(2013, 11, 22)},
    {"console": "XS", "launch_date": date(2020, 11, 10)},
    {"console": "ZXS", "launch_date": date(1982, 4, 23)},
    {"console": "iOS", "launch_date": date(2008, 7, 10)},
    {"console": "iQue", "launch_date": date(2003, 11, 17)},
]

# Genre priority mapping from most to least generic - higher takes precedence
genre_map = {
    "Misc": 0,
    "Action": 1,
    "Adventure": 2,
    "Action-Adventure": 3,
    "Party": 4,
    "Sandbox": 5,
    "Shooter": 6,
    "Platform": 7,
    "Racing": 8,
    "Sports": 9,
    "Fighting": 10,
    "Music": 11,
    "Simulation": 12,
    "Role-Playing": 13,
    "MMO": 14,
    "Puzzle": 15,
    "Strategy": 16,
    "Board Game": 17,
    "Visual Novel": 18,
    "Education": 19,
}

# Publisher and developer mapping for collapsing entities
pub_dev_map = [
    (r"\b505 games\b", "505 Games"),
    (r"\bascii\b", "ASCII"),
    (r"\bactivision\b", "Activision"),
    (r"\batari\b|\binfogrames\b", "Atari"),
    (r"\batlus\b", "Atlus"),
    (r"^avalanche (studios|software|productions)", "Avalanche"),
    (r"\bnamco\b|\bbandai\b", "Bandai Namco"),
    (r"\bbethesda\b", "Bethesda"),
    (r"\bbioware\b", "BioWare"),
    (r"^blitz", "Blitz Games"),
    (r"\bcapcom\b", "Capcom"),
    (r"^climax", "Climax"),
    (r"\bcodemasters\b", "Codemasters"),
    (r"\bcompile\b", "Compile"),
    (r"\bdigital eclipse\b", "Digital Eclipse"),
    (r"\bdigital fusion\b", "Digital Fusion"),
    (r"\bdigital goldfish\b", "Digital Goldfish"),
    (r"\bdigital illusions\b", "Digital Illusions"),
    (r"\bdigital leisure\b", "Digital Leisure"),
    (r"\bdigital dna\b", "DigitalDNA"),
    (r"\bdisney\b", "Disney"),
    (r"\beidos\b", "Eidos"),
    (r"^ea\b|\belectronic arts\b", "Electronic Arts"),
    (r"^from software", "FromSoftware"),
    (r"\bgamemill\b", "Gamemill"),
    (r"\bhudson\b", "Hudson Soft"),
    (r"\bidea factory\b", "Idea Factory"),
    (r"^intelligent (systems|games|design)", "Intelligent Systems"),
    (r"\binterplay\b", "Interplay"),
    (r"^irem", "Irem"),
    (r"^jaleco", "Jaleco"),
    (r"\bkadokawa\b", "Kadokawa"),
    (r"\bkalypso\b", "Kalypso"),
    (r"\bkemco\b", "Kemco"),
    (r"\bkoei\b|\btecmo\b", "Koei Tecmo"),
    (r"\bkonami\b", "Konami"),
    (r"\blucasarts\b", "LucasArts"),
    (r"\bmajesco\b", "Majesco"),
    (r"\bmarvelous\b", "Marvelous"),
    (r"\bmattel\b", "Mattel"),
    (r"\bmicrosoft\b|\bxbox\b", "Microsoft Studios"),
    (r"\bmidway\b", "Midway"),
    (r"^midway", "Midway"),
    (r"\bmilestone\b", "Milestone"),
    (r"\bnec\b", "NEC"),
    (r"\bnatsume\b", "Natsume"),
    (r"\bsega falcom\b", "Nihon Falcom"),
    (r"\bnintendo\b", "Nintendo"),
    (r"\bparadox\b", "Paradox"),
    (r"^probe", "Probe"),
    (r"\brare\b", "Rare"),
    (r"^rebellion", "Rebellion Developments"),
    (r"\brockstar\b", "Rockstar Games"),
    (r"\bsnk\b", "SNK"),
    (r"\bsega\b", "Sega"),
    (r"^sierra", "Sierra"),
    (r"\bsierra\b", "Sierra"),
    (r"\bscee\b|\bsony\b", "Sony"),
    (r"\bsouthpeak\b", "Southpeak"),
    (r"\bspike\b", "Spike Chunsoft"),
    (r"\bsquare\b|\benix\b", "Square Enix"),
    (r"\bthq\b", "THQ"),
    (r"\btaito\b", "Taito"),
    (r"\btakara\b", "Takara Tomy"),
    (r"\b2k\b|\btake[- ]+two\b", "Take-Two"),
    (r"^team17", "Team17"),
    (r"\btraveller\b", "Traveller's Tales"),
    (r"\bubisoft\b", "Ubisoft"),
    (r"^vicarious visions", "Vicarious Visions"),
    (r"\bvirgin\b", "Virgin"),
    (r"\bwarner\b", "Warner Bros."),
    (r"\bwayforward\b", "WayForward Technologies"),
    (r"^yuke'?s", "Yuke's"),
    (r"\bzoo games\b", "Zoo Games"),
]


def load_dataset_v2() -> pl.DataFrame:
    def apply_mapping(col: pl.Expr, mapping: list[tuple[str, str]]) -> pl.Expr:
        norm = col.str.to_lowercase().str.strip_chars()

        # Build result array - start with titlecase fallback
        result = norm.str.to_titlecase()

        # Apply in reverse so first match wins (like when / then)
        for pattern, replacement in reversed(mapping):
            mask = norm.str.contains(pattern)
            result = pl.when(mask).then(pl.lit(replacement)).otherwise(result)

        # Preserve nulls
        return pl.when(col.is_null()).then(None).otherwise(result)

    release_date = "release_date"
    release_year = "release_year"
    release_date_col = pl.col(release_date)
    launch_date = "launch_date"
    title = "title"
    console = "console"
    genre = "genre"
    genre_col = pl.col(genre)
    publisher = "publisher"
    developer = "developer"
    priority = "priority"
    franchise_base = "franchise_base"
    franchise_name = "franchise_name"
    franchise_debut = "franchise_debut"
    franchise_genre = "franchise_genre"
    str_cols = [title, publisher, developer]
    str_cols_modes = [title, "entity", "entity"]
    agg_cols = SALES_COLS + [release_date]
    identity = [title, console, publisher, developer]

    # Create a LazyFrame which contains consoles and their launch dates
    ref_lf = pl.LazyFrame(console_data).with_columns(pl.col(launch_date).cast(pl.Date))

    fixed_text = fix_encoding(CSV_FILE)

    df = (
        # Lazily scan the dataset
        pl.scan_csv(fixed_text)
        # Strip and normalize column names
        .rename(lambda c: c.strip().replace("(mil)", "_mil"))
        .with_columns(
            # Parse release_date as date
            release_date_col.str.to_date("%m/%d/%Y"),
            # Convert sales columns to float
            pl.col(SALES_COLS).str.strip_chars("$ ").cast(pl.Float64, strict=False),
        )
        .with_columns(
            # Create a temporary column for year of release
            release_date_col.dt.year().alias(release_year),
            # Remove superfluous whitespace characters
            pl.col(str_cols).str.replace_all(r"\s+", " "),
        )
        .with_columns(
            # Replace "Unknown" with null
            pl.col(str_cols).exclude(title).replace("Unknown", None)
        )
        # Join dataset with launch dates based on the console column
        .join(ref_lf, on=console, how="left")
        # Filter out releases with incorrect dates
        .filter(
            pl.any_horizontal(
                release_date_col.is_null(),
                pl.col(launch_date).is_null(),
                pl.col(release_year) >= pl.col(launch_date).dt.year(),
            )
        )
        # Filter out bundles
        .filter(
            ~pl.col(title).str.contains(
                r"(?i)\b(?:\d+\s+(?:games)?\s*in\s+\d+|collection$)\b|\s+/\s+"
            )
        )
        .with_columns(
            # Map genre to priority
            genre_col.replace_strict(genre_map, default=-1).alias(priority),
            # Collapse publishers and developers using mapping
            apply_mapping(pl.col([publisher, developer]), pub_dev_map).name.keep(),
        )
        .drop(launch_date)
        # Collect transformations
        .collect()
    )

    for col, mode in zip(str_cols, str_cols_modes):
        df = df.eda.collapse_fuzzy(col, mode, threshold=0.997)

    dup_df = (
        df.filter(pl.any_horizontal(pl.col(identity + [release_year]).is_duplicated()))
        # Group identical games within the same release year
        .group_by(identity + [release_year])
        # Aggregate to minimum release date and maximum sales values
        .agg(release_date_col.min(), pl.col(SALES_COLS).max())
    )

    df = (
        # Join back and merge aggregates to their respective columns
        df.join(dup_df, on=identity + [release_year], how="left", suffix="_agg")
        .with_columns([pl.coalesce(pl.col(f"{c}_agg"), pl.col(c)).alias(c) for c in agg_cols])
        # Re-calculate total sales from regional sales
        .with_columns(
            pl.when(pl.all_horizontal(pl.col(REGIONAL_SALES_COLS).is_null()))
            .then(None)
            .otherwise(pl.sum_horizontal(REGIONAL_SALES_COLS))
            .alias(TOTAL_SALES_COL)
        )
        .drop([f"{c}_agg" for c in agg_cols] + [release_year])
        # Deduplicate
        .unique(subset=identity, maintain_order=True)
    )

    df = df.eda.franchise_fuzzy(threshold=0.7)

    # Keep the genre with the highest priority across franchise
    franchise_genre_df = df.group_by(franchise_base).agg(
        genre_col.sort_by(priority, descending=True).first().alias(franchise_genre)
    )

    df = (
        # Pass 1: join back and fill if current genre is low-priority
        df.join(franchise_genre_df, on=franchise_base, how="left")
        .with_columns(
            pl.when(genre_col == "Misc")
            .then(pl.col(franchise_genre))
            .otherwise(genre_col)
            .alias(genre)
        )
        # Pass 2: keep the genre with the highest priority between identical titles
        .with_columns(genre_col.sort_by(priority, descending=True).first().over(title, publisher))
        .with_columns(genre_col.sort_by(priority, descending=True).first().over(title))
        .drop(priority, franchise_base, franchise_name, franchise_debut, franchise_genre)
    )

    return df

# %%
# Load dataset and verify transformations

df = load_dataset_v2()

title = "title"
console = "console"
genre = "genre"
genre_col = pl.col(genre)
launch_date = pl.col("launch_date")
release_date = pl.col("release_date")
is_anomaly = "is_anomaly"
cols = [title, "publisher", "developer"]
col_modes = [title, "entity", "entity"]

anomaly_df = df.join(launch_dates_df, on=console, how="left").with_columns(
    (
        pl.all_horizontal(
            release_date.is_not_null(),
            launch_date.is_not_null(),
            release_date.dt.year() < launch_date.dt.year(),
        )
    ).alias(is_anomaly),
)

n_anomalies = anomaly_df[is_anomaly].sum()
print("Number of games with an anomalous release date:", n_anomalies)

n_bundles = df.filter(
    pl.col(title).str.contains(r"(?i)\b(?:\d+\s+(?:games)?\s*in\s+\d+|collection$)\b|\s+/\s+")
).height
print("Number of bundles:", n_bundles)

# Group by title and verify the number of unique genres per group is one
n_genre_collisions = df.group_by(title).agg(genre).filter(genre_col.list.n_unique() > 1).height
gta_genres = (
    df.filter(pl.col(title).str.contains("(?i)grand theft auto"))
    .select(genre_col.unique().sort())[genre]
    .to_list()
)

print("Number of genre mismatches:", n_genre_collisions)
print("Genres across GTA games:", gta_genres)

# Verify collisions collapse
for col, mode in zip(cols, col_modes):
    collisions_df = df.eda.collisions_fuzzy(col, mode, threshold=0.997)
    print(f"Number of {col} fuzzy collisions: {collisions_df.height}")

for col in cols[1:]:
    df.eda.display_groups_by_first_word(col, threshold=500)

display(df)

# %% [markdown]
# ### Structure of missingness

# %% [markdown]
# #### Missingness in columns

# %%
# Plot missingness in columns

# Keep columns with missing values
cols = pl.col(df.null_count().eda.columns_by_pred(pl.all() > 0))

# Get null count per column and globally
viz_df = (
    df.select(cols.null_count())
    .with_columns(
        cols / df.height,
        (pl.sum_horizontal(cols) / (df.height * df.width)).alias("Dataset"),
    )
    .rename(COL_LABELS, strict=False)
    .transpose(include_header=True, header_name="column", column_names=["null_count"])
    .sort([pl.col("column") != "Dataset", "null_count"], descending=[True, True])
)


# Create a bar plot
fig = px.bar(
    viz_df,
    x="null_count",
    y="column",
    color="column",
    orientation="h",
    labels={"null_count": "Missingness (%)", "column": "Column"},
    title="Missingness in Columns",
)

# Change X-axis tick format to percentage
fig.update_xaxes(tickformat=".1%")
fig.update_layout(showlegend=False)

fig.show()

# %%
# Plot a Missingno matrix to show data completeness

# Get column names of columns with missing values
cols = df.null_count().eda.columns_by_pred(pl.all() > 0)

# Generate a binary matrix containing values which are either 0 (present) or 1 (missing)
viz_df = df.select(pl.col(cols).is_null().cast(pl.Int8)).rename(COL_LABELS, strict=False)

# Create a binary heatmap mapping availability to colors
fig = px.imshow(
    viz_df,
    labels=dict(x="Column", y="Row Index", color="Missing"),
    title="Data Availability Matrix",
    zmin=0,
    zmax=1,
)

# Hide side color bar and reverse colors
fig.update_layout(
    coloraxis_showscale=False,
    coloraxis_reversescale=True,
)

fig.show()

# %% [markdown]
# #### Sales availability across dataset

# %%
# plot percentage of observations by number of available regional sales values

viz_df = (
    # Get counts of available regional sales per observation
    df.select(
        pl.sum_horizontal(pl.col(SALES_COLS).is_not_null())
        .cast(pl.String)
        .value_counts(normalize=True, sort=True)
        .struct.rename_fields(["num_regions", "proportion"])
        .struct.unnest()
    )
)

# Create a bar plot
fig = px.bar(
    viz_df,
    x="proportion",
    y="num_regions",
    color="num_regions",
    orientation="h",
    labels={"num_regions": "Regional Sales (#)", "proportion": "Observations (%)"},
    title="Number of Observations per Available Regional Sales Values",
)

# Change X-axis tick format to percentage
fig.update_xaxes(tickformat=".1%")
fig.update_layout(showlegend=False)

fig.show()

# %%
# Check if there are observations with regional sales but missing total sales

n_missing_total_sales = df.filter(
    (pl.any_horizontal(pl.col(REGIONAL_SALES_COLS).is_not_null()))
    & pl.col(TOTAL_SALES_COL).is_null()
).height

print(
    f"Number of observations with missing total sales and non-missing regional sales: {n_missing_total_sales}"
)

# %% [markdown]
# #### Data availability over time

# %%
# Plot data availability over time

rd_col = pl.col("release_date")

# Filter out columns with no missing values and exclude release_date as it is being grouped by
cols = df.null_count().eda.columns_by_pred(cs.exclude(rd_col) > 0)

# Calculate availability proportions by year of release_date
viz_df = (
    df.filter(rd_col.is_not_null())
    .group_by(rd_col.dt.year().alias("year"))
    .agg(pl.col(cols).count() / pl.len())
    .sort("year")
    .rename(COL_LABELS, strict=False)
)

# Create a line plot showing availability over time
fig = px.line(
    viz_df,
    x="year",
    y=[COL_LABELS[c] for c in cols],
    line_shape="spline",
    labels={"year": "Year", "value": "Availability (%)"},
    title="Data Availability Over Time",
)

# Format values as percentages
fig.update_yaxes(tickformat=".0%")

# Update hover template to improve readability
fig.for_each_trace(
    lambda t: t.update(hovertemplate=("<b>%{fullData.name}</b>: %{y:.0%}<extra></extra>"))
)

# Show hover data for all lines at once
fig.update_layout(
    hovermode="x",
    legend_title_text="Column",
)

fig.show()

# %% [markdown]
# #### Sales availability across consoles

# %%
# Plot sales availability across regions by console

col = "console"
sales_cols = pl.col(SALES_COLS)
threshold = 50

global_availability_mean = df.select(sales_cols.count() / pl.len())

# Percentage of sales availability across regions by console
base_df = df.group_by(col).agg(
    # Raw average availability per group
    (sales_cols.count() / pl.len() * 100).name.suffix("_raw"),
    # Count of non-nulls
    sales_cols.count().name.suffix("_count"),
)

# Average count of non-nulls across all groups
alpha = base_df.select(cs.ends_with("_count").mean().name.replace("_count", "")).select(
    # Use a minimum threshold if average is too low
    pl.when(sales_cols > threshold).then(sales_cols).otherwise(pl.lit(threshold))
)

# Smooth groups by pulling toward the average global availability and convert to percentage
base_df = base_df.with_columns(
    *[
        pl.col(f"{c}_raw")
        .eda.bayesian_smooth(f"{c}_count", global_availability_mean[c], alpha=alpha[c])
        .alias(c)
        for c in SALES_COLS
    ],
    pl.sum_horizontal(cs.ends_with("_count")).alias("total_sum"),
)

# Get consoles with no sales coverage
no_sales = base_df.filter(pl.col("total_sum") == 0)[col].sort().to_list()

if len(no_sales) > 0:
    print("Consoles with no sales coverage:")
    for vals in batched(no_sales, 4):
        print(*[f"{v:>8}" for v in vals])

# Filter out consoles containing no availability
viz_df = base_df.filter(pl.col("total_sum") > 0).sort("total_sum", descending=True)

raw = viz_df.select(cs.ends_with("_raw")).to_numpy()
counts = viz_df.select(cs.ends_with("_count")).to_numpy()

# Custom data for hover info
customdata = np.stack([raw, counts], axis=-1)

# Text annotations for consoles with low availability
text = np.where(
    counts < 10,
    "⚠",
    np.where(counts < 30, "·", ""),
)

# Create a heatmap plot mapping availability values to gradient colors
fig = px.imshow(
    viz_df.select(SALES_COLS),
    x=[COL_LABELS[c] for c in SALES_COLS],
    y=viz_df[col],
    aspect="auto",
    zmin=0,
    zmax=100,
    labels=dict(x="Region", y="Console", color="Availability"),
    title="Regional Sales Availability Across Consoles",
)

# Add custom data and update hover template
fig.update_traces(
    customdata=customdata,
    hovertemplate="<b>%{x}</b>: %{y}<br>"
    "Smooth: %{z:.1f}%<br>"
    "Raw: %{customdata[0]:.1f}%<br>"
    "Count: %{customdata[1]}<extra></extra>",
    text=text,
    texttemplate="%{text}",
)

# Update plot height
fig.update_layout(height=20 * viz_df.height + 100)

# Update Colorbar title and tick values & labels
fig.update_coloraxes(
    colorbar_title="Availability (%)",
    colorbar_tickvals=[0, 25, 50, 75, 100],
    colorbar_ticktext=["0%", "25%", "50%", "75%", "100%"],
)

fig.show()

# %% [markdown]
# #### Missingness in release date

# %% [markdown]
# Explore a few characteristics of observations with missing `release_date`.

# %%
# Split the dataset by the availability of release_date
null_dates_df = df.filter(pl.col("release_date").is_null()).drop("release_date")
non_null_dates_df = df.filter(pl.col("release_date").is_not_null()).drop("release_date")

num = cs.numeric()
non_num = ~num

# Display a short statistical summary for observations with and without a release date
print("Numerical statistics (non-missing vs. missing release date):")
non_null_dates_df.select(num).eda.describe()
null_dates_df.select(num).eda.describe()

print("Non-numberical statistics (non-missing vs. missing release date):")
non_null_dates_df.select(non_num).eda.describe()
null_dates_df.select(non_num).eda.describe()

# %%
# Plot a side-by-side view of Missingno matrices for observations with & without release_date

frames = [non_null_dates_df, null_dates_df]

# Keep columns with missing values
cols = [f.null_count().eda.columns_by_pred(pl.all() > 0) for f in frames]

# Generate data availability matrices
viz_dfs = [
    f.select(pl.col(c).is_null().cast(pl.Int8)).rename(COL_LABELS, strict=False)
    for f, c in zip(frames, cols)
]

# Create a 1x2 subplots Figure
fig = make_subplots(
    rows=1,
    cols=2,
    subplot_titles=("Non-Missing Release Date", "Missing Release Date"),
    y_title="Row Index",
)

# Create the heatmap plots and add to subplots
for i, viz_df in enumerate(viz_dfs, 1):
    t = px.imshow(viz_df, zmin=0, zmax=1)
    fig.add_trace(t.data[0], row=1, col=i)

fig.update_xaxes(title_text="Column")

# Reverse Y-axes to match the image coordinate system
fig.update_yaxes(autorange="reversed")

# Reverse colors and hide colorbar
fig.update_layout(
    title="Data Availability Matrices (Side-by-Side)",
    hovermode=False,
    coloraxis_reversescale=True,
    coloraxis_showscale=False,
)

fig.show()

# %%
# Examine exclusive values for observations with and without release_date


def exclusive_uniques(df_left: pl.DataFrame, df_right: pl.DataFrame, col: str) -> set:
    # Create a set object of unique values in col for each DataFrame
    left_vals = set(df_left[col].drop_nulls().unique().to_list())
    right_vals = set(df_right[col].drop_nulls().unique().to_list())

    # Return values in the left set which are not in the right set
    return left_vals - right_vals


def print_cols_exclusives(
    df_left: pl.DataFrame, df_right: pl.DataFrame, cols: list[str], title: str
) -> None:
    exclusives = []

    print(f"{title}:")

    for col in cols:
        # Get values in col exclusive to df_left
        excl = exclusive_uniques(df_left, df_right, col)
        print(f"  {col:<15}{len(excl)}")
        # Store exclusives for filtering
        exclusives.append((col, excl))

    print()

    # Filter out columns containing many exclusive values
    exclusives = list(filter(lambda v: 0 < len(v[1]) <= 20, exclusives))
    if len(exclusives) > 0:
        print("Exclusive values:")

        for col, excl in exclusives:
            print(f"  {col}: {excl}")

        print()


cols = ["title", "genre", "console", "publisher", "developer"]

print_cols_exclusives(
    null_dates_df,
    non_null_dates_df,
    cols,
    "Number of unique values exclusive to observations without a release date",
)

print_cols_exclusives(
    non_null_dates_df,
    null_dates_df,
    cols,
    "Number of unique values exclusive to observations with a release date",
)

# %% [markdown]
# #### Observations
#
# - Out of 12 columns 9 contain missing values, with `sales` and `critic_score` exhibiting a very high degree of missingness.
# - With _Unknown_ values replaced by null, the `publisher` and `developer` columns now contain a moderate degree of missingness, as does the `release_date` column.
# - As a whole, the dataset exhibits substantial missingness, though this is highly concentrated in sales-related columns.
# - The vast majority of observations have no sales values.
# - The rest of the observations have primarily between 2 to 4 sales values.
# - Conditional on the availability of at least one regional sales value, a total sales value is guaranteed to be available.
# - Sales availability is largely concentrated between approximately mid-1990s to late 2010s.
# - Critic score availability over time follows a similar trend to that of the sales columns.
# - Publisher and developer availability remains close to 100%, with only sporadic dips over time, which do not appear to be driven purely by year of release.
# - Japan contains low availability throughout the vast majority of consoles.
# - Consoles exhibit patterns consistent with right-censoring (e.g., PS5), while others show low availability likely attributable to source bias or unobserved historical data (e.g., SNES).
# - _PC_ has the highest frequency in the `console` column, but sales coverage for _PC_ titles is especially low.
# - Out of all consoles, only a handful contain significant sales coverage. Many popular consoles (e.g, PS5), including Operating Systems and platforms (e.g, iOS and PSN), have almost no sales availability.
# - There are no strong signals that observations with missing `release_date` correspond to a distinct subset of consoles or publishers; high exclusivity in titles and developers is consistent with sparsity and source fragmentation rather than structural separation.
# - Small exclusivity in consoles (iQue and FDS) is likely attributable to unobserved historical data and source bias.

# %% [markdown]
# ### Summary and conclusions
#
# The dataset appears to be source fragmented and missing values are concentrated in sales and critic score related columns. The structure of missingness exhibits patterns consistent with unobserved historical data, right-censoring, and source bias.
# Due to source fragmentation and sales and critic score sparsity, only a handful of consoles and a small window of release dates contain meaningful coverage. It's recommended to reflect on relative patterns, rather than absolute figures.

# %% [markdown]
# ## Part 3: Feature-Level Analysis
#
# In this section the statistical characteristics and relationships of features are explored. This part utilizes insights gained in previous parts to understand the data, and how it can be used in modeling.

# %% [markdown]
# ### Univariate analysis

# %% [markdown]
# #### Numerical features

# %%
# Plot the distribution of sales across regions


# Add a mask column for flagging outliers
def mask_outliers(df: pl.DataFrame, columns: IntoExpr) -> pl.DataFrame:

    cols = df.eda.to_names(columns)
    expr = pl.col(cols)

    # Calculate 25th and 75th percentiles, and IQR of all columns
    stats = df.select(
        expr.quantile(0.25).name.suffix("_q1"), expr.quantile(0.75).name.suffix("_q3")
    ).with_columns((cs.ends_with("_q3") - cs.ends_with("_q1")).name.suffix("_iqr"))

    # Calculate lower and upper fences
    lower = stats.select((cs.ends_with("_q1") - cs.ends_with("_iqr") * 1.5).name.replace("_q1", ""))
    upper = stats.select((cs.ends_with("_q3") + cs.ends_with("_iqr") * 1.5).name.replace("_q3", ""))

    return df.with_columns(
        [
            pl.when(
                # Flag as outlire if any column contains an outlier
                pl.any_horizontal([(pl.col(c) < lower[c]) | (pl.col(c) > upper[c]) for c in cols])
            )
            .then(pl.lit(True))
            .otherwise(pl.lit(False))
            .alias("mask")
        ]
    )


lin_sales_cols = cs.by_name([f"{c}_lin" for c in SALES_COLS])
log_sales_cols = cs.by_name([f"{c}_log" for c in SALES_COLS])
hover_cols = ["title", "console"]

# Scale sales values to log10 and keep linear values
base_df = df.select(
    pl.col(SALES_COLS).name.suffix("_lin"),
    pl.col(SALES_COLS).log10().name.suffix("_log"),
    *hover_cols,
)

# Get mask and add hover info for outliers
base_df = mask_outliers(base_df, lin_sales_cols | log_sales_cols).select(
    cs.exclude(hover_cols),
    *[
        pl.when("mask")
        .then(
            pl.format(
                "<br>".join([f"{COL_LABELS[c]}: {{}}" for c in [r] + hover_cols]),
                pl.col(f"{r}_lin").round(2),
                *hover_cols,
            )
        )
        .alias(f"{r}_hover")
        for r in SALES_COLS
    ],
)

# Get global min and max sales values in linear space
min_sale = base_df.select(pl.min_horizontal(lin_sales_cols.min())).item()
max_sale = base_df.select(pl.max_horizontal(lin_sales_cols.max())).item() * 1.1

# Scale min and max to log10
min_sale_log = np.log10(min_sale)
max_sale_log = np.log10(max_sale)

# Generate human-readable tick labels for the values in log10 scale
ticks = get_transformed_ticks(min_sale, max_sale, steps=[10, 20, 50])
tickvals = list(ticks.values())
ticktext = list(ticks.keys())

for scale in ("_log", "_lin"):
    viz_df = base_df.select(cs.ends_with(scale).name.replace(scale, ""), cs.ends_with("_hover"))
    is_lin = scale == "_lin"

    fig = go.Figure()

    # Add a violin chart for each region
    for region in SALES_COLS:
        fig.add_violin(
            x=viz_df[region],
            orientation="h",
            box_visible=is_lin,
            meanline_visible=is_lin,
            width=2 if is_lin else 3,
            box_width=0.7,
            jitter=0.1,
            bandwidth=0.2,
            points="outliers",
            side="positive",
            spanmode="hard",
            hoveron="violins+points" if is_lin else "points",
            customdata=viz_df[f"{region}_hover"],
            hovertemplate="%{customdata}<extra></extra>",
            name=COL_LABELS[region],
        )

    # Update axes
    if is_lin:
        fig.update_xaxes(
            tickmode="auto",
            range=[min_sale, max_sale],
            minallowed=min_sale,
            maxallowed=max_sale,
            title="Sales (Millions, Linear Scale)",
        )
    else:
        fig.update_xaxes(
            tickmode="array",
            tickvals=tickvals,
            ticktext=ticktext,
            range=[min_sale_log, max_sale_log],
            minallowed=min_sale_log,
            maxallowed=max_sale_log,
            title="Sales (Millions, Log Scale)",
        )

    # Add labels and dropdown buttons
    fig.update_layout(
        yaxis={"categoryorder": "array", "categoryarray": SALES_COL_LABELS[::-1]},
        title=f"Regional Sales Distributions ({'Linear' if is_lin else 'Log'} Scale)",
        height=500,
    )

    fig.show()

# %%
# Print share of sales of top 5% of sales across regions

sales_cols = pl.col(SALES_COLS)

# Sum total and top 5% of sales and calculate percentages
sales_df = df.select(
    sales_cols.sum(),
    sales_cols.filter(sales_cols >= sales_cols.quantile(0.95)).sum().name.suffix("_top5p_sum"),
).select((cs.ends_with("_top5p_sum") / sales_cols).name.replace("_top5p_sum", ""))

viz_df = sales_df.rename(COL_LABELS, strict=False).unpivot()

fig = px.bar(
    viz_df,
    y="variable",
    x="value",
    color="variable",
    labels={"variable": "Region", "value": "Share of Sales (Top 5%)"},
    title="Share of Top 5% of Regional Sales",
)

fig.update_xaxes(tickformat=".0%")
fig.update_layout(showlegend=False)

fig.show()

# %%
# Plot critic scores distribution

col = "critic_score"
cs_min, cs_max = df[col].min(), df[col].max()

# Calculate bin boundaries, breaks, and labels
n_bins = int((cs_max - cs_min) * 2)
bin_width = round((cs_max - cs_min) / n_bins, 1)
boundaries = [round(cs_min + i * bin_width, 1) for i in range(n_bins + 1)]
boundaries_len = len(boundaries)
labels = [
    f"[{boundaries[i]}, {boundaries[i + 1]}" + (")" if i < boundaries_len - 2 else "]")
    for i in range(boundaries_len - 1)
]
breaks = boundaries[1:-1]

viz_df = (
    df.filter(pl.col(col).is_not_null())
    # Bin critic scores into buckets
    .with_columns(
        pl.col(col).cut(breaks=breaks, labels=labels, left_closed=True).alias("bin_range")
    )
    .group_by("bin_range")
    .agg(
        # Count of items in each bucket
        pl.len().alias("bin_count"),
        # Get the top 10 names in each bucket for the hover info column
        pl.col("title").top_k_by(TOTAL_SALES_COL, k=10).alias("top_5_titles"),
    )
    .with_columns(
        # Format column for hover info
        pl.format(
            "<br>  {}",
            pl.col("top_5_titles")
            .list.unique(maintain_order=True)
            .list.head(5)  # Get top 5 unique titles
            .list.join("<br>  "),
        )
    )
    .sort("bin_range")
)

# Hover template showing bucket ranges, counts, and top titles
hovertemplate = (
    "<b>Range:</b> %{x}<br>"
    + "<b>Count:</b> %{y}<br>"
    + "<b>Top 5 Titles:</b> %{customdata}<extra></extra>"
)

# Custom data used by the hover template
customdata = viz_df["top_5_titles"]

# Create subplots of two rows with a shared X-axis
fig = make_subplots(rows=2, cols=1, shared_xaxes=True, row_heights=[0.2, 0.8])

# Add a box subplot to show the spread of critic scores
fig.add_box(x=df[col], boxmean=True, name="", row=1, col=1)

# Add a bar subplot to show the distribution of critic scores
fig.add_bar(
    x=viz_df["bin_range"],
    y=viz_df["bin_count"],
    width=bin_width * 2,
    marker_line=dict(color=cat_colors[1], width=2),
    customdata=customdata,
    hovertemplate=hovertemplate,
    row=2,
    col=1,
)

# Update X-axis title
fig.update_xaxes(title="Critic Score", dtick=2, row=2, col=1)

# Update Y-axis title for both subplots
fig.update_yaxes(title="Spread", row=1, col=1)
fig.update_yaxes(title="Count", row=2, col=1)

# Layout adjustments
fig.update_layout(
    title_text=f"{COL_LABELS[col]} Distribution",
    showlegend=False,
    height=580,
)
fig.show()

# %% [markdown]
# ##### Observations
#
# - Sales distributions appear to be positively skewed (right-skewed) across all regions.
# - Sales are highly concentrated, with the top 5% of sales accounting for roughly 40% of total regional sales. This indicates that overall sales performance is driven by a relatively small subset of games.
# - Due to the strong positive skew in sales distributions, mean values are likely influenced heavily by a small number of extremely successful games.
# - Critic scores distribution appears to be negatively skewed (left-skewed), with most scores clustered toward the higher end of the scale. The average score is approximately 7.2, and scores below 5 are rare, suggesting that critically reviewed games tend to receive moderately positive ratings.

# %% [markdown]
# #### Categorical features

# %%
# Plot the distributions of top 10 categories in categorical columns

cols = ["console", "genre", "publisher", "developer"]
n_cats = 10

# Calculate counts of unique values and Gini coefficients
counts_df = df.select(
    pl.col(cols)
    .drop_nulls()
    .value_counts(sort=True, normalize=True)
    .struct.with_fields(gini=pl.field("proportion").eda.gini())
    .implode()
)

# Generate subplot titles with Gini coefficients
gcs = {col.name: col.explode().struct.unnest()["gini"].first() for col in counts_df.iter_columns()}
titles = [f"{COL_LABELS[col]} (Gini Coefficient={gcs[col]:.2f})" for col in cols]

# Set the number of subplot rows and columns
n_cols = 2
n_rows = int(np.ceil(len(cols) / n_cols))

# Create subplots with a shared X-axis
fig = make_subplots(
    rows=n_rows,
    cols=n_cols,
    vertical_spacing=0.1,
    subplot_titles=titles,
    shared_xaxes=True,
)

for i, col in enumerate(cols):
    # Get top 10 categories by value counts
    viz_df = (
        counts_df[col]
        .explode()
        .struct.rename_fields(["col", "prop", "gini"])
        .struct.unnest()
        .head(n_cats)
    )

    # Calculate current subplot row and column
    r = i // n_cols + 1
    c = i % n_cols + 1

    # Add a bar subplot
    fig.add_bar(
        x=viz_df["prop"],
        y=viz_df["col"],
        orientation="h",
        row=r,
        col=c,
    )
    fig.update_xaxes(title="Proportion (%)", row=r, col=c)

# Update hover template for all traces
fig.update_traces(hovertemplate="%{y}: %{x:.1%}<extra></extra>")

# Get largest proportion
max_prop = counts_df.select(pl.max_horizontal(pl.all().explode().struct[1].head(1))).item()

# Change ticks to percentage and extend max limit for margins
fig.update_xaxes(tickformat=".0%", range=[0, max_prop * 1.05])

# Reverse Y-axis to sort from highest to lowest
fig.update_yaxes(autorange="reversed")

# Layout adjustments
fig.update_layout(
    title=f"Top {n_cats} Categories Distributions",
    showlegend=False,
    height=100 + n_rows * n_cats * 30,
)

fig.show()

# %% [markdown]
# ##### Observations
#
# - Genre distribution is relatively balanced compared to the other categorical features, though some genres appear more frequently than others. This is reflected in its moderate Gini coefficient (0.45).
# - In contrast, the console, publisher, and developer distributions are highly skewed, with a small number of categories responsible for a large share of observations. Their high Gini coefficients (0.7-0.85) indicate strong concentration.

# %% [markdown]
# #### Temporal features

# %%
# Plot count of observations by release_date

rd = "release_date"
rd_col = pl.col(rd)

viz_df = (
    df.filter(rd_col.is_not_null())
    .sort(rd_col)
    # Group dates every one month
    .group_by_dynamic(rd_col, every="1mo")
    .agg(pl.len().alias("count"))
)

# Create a line plot for observation counts over time
fig = px.line(
    viz_df,
    x=rd,
    y="count",
    line_shape="spline",
    labels={"count": "Count of Observations", rd: "Date"},
    title="Count of Observations by Release Date (Monthly)",
)

# Layout adjustments
fig.update_layout(showlegend=False)

fig.show()

# %% [markdown]
# ##### Observations
#
# - Similar to sales availability over time, observations are concentrated between approximately mid-1990s and late 2010s.
# - Observations appear to be primarily clustered in T3 (3rd tertile, Oct-Jan) of each fiscal year. This phenomenon is present in many markets which experience growth in sales at this time of the year.

# %% [markdown]
# ### Multivariate analysis

# %% [markdown]
# #### Numerical-numerical features

# %%
# Plot the correlation matrix of numerical features

viz_df = (
    # Compress sales to log scale to deal with massive outliers
    df.with_columns(pl.col(SALES_COLS).log())
    .eda.corr(method="spearman")
    .rename(COL_LABELS, strict=False)
)

# Create a heatmap plot mapping correlation values to gradient colors
fig = px.imshow(
    viz_df,
    y=viz_df.columns,
    text_auto=".1g",
    zmin=-1,
    zmax=1,
    title="Correlation Matrix: Regional Sales and Critic Score (Log Scale)",
)

fig.update_layout(hovermode=False)

fig.show()

# %%
# Plot a scatter matrix of sales across regions by critic_score

cs_col = "critic_score"
sales_cols = pl.col(SALES_COLS)
hover_cols = ["title", "console"]
cell_size = 250

# Get min and max values in critic_score
min_score, max_score = df[cs_col].min(), df[cs_col].max()

# Generate bucket ranges
buckets = [f"[{min_score:.0f}-5]", "(5-7]", "(7-9]", f"(9-{max_score:.0f}]", "N/A"]

# Compress sales values and bin critic_score into buckets
viz_df = df.select(
    *hover_cols,
    sales_cols.name.suffix("_linear"),
    sales_cols.log1p(),
    # Fill missing critic score values with a sentinel containing its own bucket
    pl.col(cs_col).fill_null(max_score + 2).cut([5, 7, 9, max_score + 1], labels=buckets),
    pl.lit(1).alias("size"),
).with_columns(
    # Add linear sales values and hover_cols to be used by hover box
    pl.when(cs.ends_with("_linear").is_not_null())
    .then(cs.ends_with("_linear").round(2).cast(pl.String))
    .otherwise(pl.lit("N/A"))
    .name.replace("_linear", "_hover"),
    *[pl.col(c).name.suffix("_hover") for c in hover_cols],
)

custom_data = viz_df.select(cs.ends_with("_hover")).columns

# Create a scatter matrix plot to show relationships between sales across regions by critic_score
fig = px.scatter_matrix(
    viz_df,
    dimensions=SALES_COLS,
    color=cs_col,
    opacity=0.7,
    size="size",
    size_max=10,
    category_orders={cs_col: buckets},
    labels=COL_LABELS,
    hover_data={"size": False, cs_col: False},
    custom_data=custom_data,
    title="Scatter Matrix: Regional Sales by Critic Scores (Log Scale)",
    width=len(SALES_COLS) * cell_size,
    height=len(SALES_COLS) * cell_size,
)

# Reverse trace order to improve clusters visibility
fig.data = fig.data[::-1]


# Update hovertemplate to show linear sales values across all regions
fig.update_traces(
    hovertemplate=(
        "".join(
            [
                f"{COL_LABELS[c.replace('_hover', '')]}: %{{customdata[{i}]}}<br>"
                for i, c in enumerate(custom_data)
            ]
            + ["<extra></extra>"]
        )
    ),
    marker_line_width=0.5,
    showlegend=False,
)

# Assign each category in critic_score to its own legend group
fig.for_each_trace(lambda t: t.update(legendgroup=t.name))

# Create dummy plots to show opaque legend entry icons
for i, cat in enumerate(buckets):
    fig.add_scatter(
        x=[None],
        y=[None],
        mode="markers",
        name=cat,
        legendgroup=cat,  # Assign the same legend group names
        marker=dict(size=10, color=cat_colors[i]),
        showlegend=True,
    )

# Convert tick labels to linear and set axes range
for i, col in enumerate(SALES_COLS):
    lin_col = viz_df[f"{col}_linear"]

    # Generate tick values and labels in increments of 5 millions
    ticks = get_transformed_ticks(lin_col.min(), lin_col.max(), scale=np.log1p, steps=[100, 500])
    tickvals = list(ticks.values())
    ticktext = list(ticks.keys())

    # Calculate the data bounds
    min_log, max_log = viz_df[col].min(), viz_df[col].max()
    margin = (max_log - min_log) * 0.1

    axis_id = i + 1 if i > 0 else ""
    fig.update_layout(
        {
            f"xaxis{axis_id}": dict(
                tickvals=tickvals,
                ticktext=ticktext,
                range=[min_log - margin, max_log + margin],
                autorange=False,
            ),
            f"yaxis{axis_id}": dict(
                tickvals=tickvals,
                ticktext=ticktext,
                range=[min_log - margin, max_log + margin],
                autorange=False,
            ),
        }
    )

# Add OLS trendlines to off-diagonal plots
for i, j in permutations(range(len(SALES_COLS)), 2):
    row = SALES_COLS[i]
    col = SALES_COLS[j]

    # Extract and Fit
    mask = viz_df[row].is_not_null() & viz_df[col].is_not_null()
    cell_df = viz_df.filter(mask)

    X = cell_df[col].to_numpy().reshape(-1, 1)
    y = cell_df[row].to_numpy()

    # Use a linear regression model which is relatively more resistant to outliers
    model = HuberRegressor(epsilon=1.35).fit(X, y)

    x_min, x_max = X.min(), X.max()
    padding = (x_max - x_min) * 0.5

    # Pad min and max to extend trendlines
    x_ext = np.array([[x_min - padding], [x_max + padding]])
    y_ext = model.predict(x_ext)

    # Add a layered shape to place trendlines on top of markers
    fig.add_shape(
        type="line",
        x0=x_ext[0][0],
        y0=y_ext[0],
        x1=x_ext[1][0],
        y1=y_ext[1],
        # Reference the specific subplot axes
        xref=f"x{j + 1 if j > 0 else ''}",
        yref=f"y{i + 1 if i > 0 else ''}",
        line=dict(color="red", width=4, dash="dash"),
        layer="above",
    )

fig.show()

# %% [markdown]
# ##### Observations
#
# - Regional sales exhibit moderate to strong positive correlations in most cases, indicating that titles which perform well in one market often perform well in others.
# - As the market with the highest impact on total sales and availability, regional sales in _North America_ show a very strong correlation with _Total_ sales.
# - In contrast, regional sales in _Japan_ exhibit weaker correlations with other regions, suggesting regional differences in market preferences, which might be due to low availability.
# - Critic scores display a weak-to-moderate positive correlation with sales across regions, indicating that higher-rated games tend to sell slightly better, though the relationship is not strong.

# %% [markdown]
# #### Numerical-categorical features

# %% [markdown]
# ##### Sales by categorical columns

# %%
# Plot sales distribution across regions by categorical columns

cols = ["genre", "console", "publisher", "developer"]
sales_cols = pl.col(SALES_COLS)
n_cats = 10
threshold = 50

for col in cols:
    global_metrics = df.select(
        sales_cols.mean().name.suffix("_mean"), sales_cols.median().name.suffix("_median")
    )

    # Calculate sales metrics across regions grouped by categories
    base_df = (
        df.select(sales_cols, pl.col(col))
        .group_by(col)
        .agg(
            sales_cols.sum().name.suffix("_sum"),
            sales_cols.mean().name.suffix("_mean"),
            sales_cols.median().name.suffix("_median"),
            # Sum count of availability within each group across regions
            sales_cols.is_not_null().sum().name.suffix("_count"),
        )
    )

    # Use average availability as alpha
    alpha = base_df.select(
        pl.when(cs.ends_with("_count").mean() > threshold)
        .then(cs.ends_with("_count").mean())
        .otherwise(threshold)
        .name.replace("_count", "")
    )

    # Smooth average and median values
    base_df = base_df.with_columns(
        [
            pl.col(f"{c}_{m}")
            .eda.bayesian_smooth(f"{c}_count", global_metrics[f"{c}_{m}"], alpha=alpha[c])
            .name.suffix("_smooth")
            for m in ("mean", "median")
            for c in SALES_COLS
        ]
    ).fill_null(strategy="zero")

    metrics = [
        ("sum", "Total Market Share (Sum)"),
        ("mean_smooth", "Average Performance (Smoothed)"),
        ("median_smooth", "Typical Performance (Smoothed)"),
    ]

    column_titles = ["Sales (Millions)", "Average Sales (Millions)", "Median Sales (Millions)"]

    fig = make_subplots(
        rows=1,
        cols=3,
        subplot_titles=[m[1] for m in metrics],
        horizontal_spacing=0.15,
    )

    # Hover template to show count per category
    hovertemplate = (
        "<b>%{fullData.name}</b><br>%{y}<br>Sales: %{x}<br>Count: %{customdata}<extra></extra>"
    )

    for i, (metric, title) in enumerate(metrics, 1):
        viz_df = base_df.sort(pl.sum_horizontal(cs.ends_with(metric)), descending=True).head(n_cats)

        # Add a stacked bar plot
        for j, region in enumerate(SALES_COLS):
            fig.add_bar(
                x=viz_df[f"{region}_{metric}"],
                y=viz_df[col],
                orientation="h",
                legendgroup=region,
                showlegend=(i == 1),
                marker_color=cat_colors[j % len(cat_colors)],
                name=COL_LABELS[region],
                customdata=viz_df[f"{region}_count"],
                hovertemplate=hovertemplate,
                row=1,
                col=i,
            )

    fig.update_yaxes(autorange="reversed")
    fig.update_yaxes(title=COL_LABELS[col], row=1, col=1)
    for i, t in enumerate(column_titles, 1):
        fig.update_xaxes(title=t, row=1, col=i)

    # Layout adjustments
    fig.update_layout(
        title=f"Distribution of Regional Sales by Top {n_cats} {COL_LABELS[col]}s",
        barmode="stack",
        height=100 + n_cats * 30,
        legend_traceorder="normal",
    )

    fig.show()

# %%
# Plot the distribution of share of sales across regions by categorical columns

cols = ["genre", "console", "publisher", "developer"]
sales_cols = pl.col(SALES_COLS)

n_cats = 10
n_cols = len(SALES_COLS)
n_rows = 1

for col in cols:
    sales_df = (
        df.select(col, sales_cols)
        .group_by(col)
        .agg(sales_cols.sum())
        # Divide sums of sales in each category by all categories
        .with_columns([pl.col(c) / pl.col(c).sum() for c in SALES_COLS])
    )

    # Create a subplots figure
    fig = make_subplots(
        rows=n_rows,
        cols=n_cols,
        subplot_titles=[COL_LABELS[c] for c in SALES_COLS],
        horizontal_spacing=0.08,
    )

    for i, region in enumerate(SALES_COLS):
        # Get top 10 categories in each region
        viz_df = sales_df.sort(region, descending=True).head(n_cats)

        # Calculate subplot row and column
        r = i // n_cols + 1
        c = i % n_cols + 1

        # Add a bar subplot
        fig.add_bar(
            x=viz_df[region],
            y=viz_df[col],
            orientation="h",
            name=COL_LABELS[region],
            row=r,
            col=c,
        )

    # Axes adjustments
    fig.update_xaxes(title="Sales Share (%)", tickformat=".1%", range=[0, 0.25])
    fig.update_yaxes(autorange="reversed")
    fig.update_yaxes(title=COL_LABELS[col], row=1, col=1)

    # Layout adjustments
    fig.update_layout(
        title=f"Distribution of Regional Sales Shares by Top {n_cats} {COL_LABELS[col]}s",
        showlegend=False,
        height=100 + n_rows * n_cats * 30,
    )

    fig.show()

# %% [markdown]
# ##### Critic scores by genre, console, publisher, and developer

# %%
# Plot the distribution of critic scores by genre, console, publisher and developer

cols = ["genre", "console", "publisher", "developer"]
cs_col = "critic_score"
n_cats = 10

threshold = 50
global_mean = df[cs_col].mean()
max_score = df[cs_col].max()

for col in cols:
    viz_df = (
        df.filter(pl.col(cs_col).is_not_null())
        .group_by(col)
        .agg(pl.col(cs_col).mean(), pl.len().alias("count"))
    )

    alpha = max(threshold, viz_df["count"].mean())

    viz_df = (
        viz_df.with_columns(pl.col(cs_col).eda.bayesian_smooth("count", global_mean, alpha=alpha))
        .sort(cs_col, descending=True)
        .head(n_cats)
    )

    # Create a bar plot
    fig = px.bar(
        viz_df,
        x=cs_col,
        y=col,
        color=col,
        orientation="h",
        hover_data=["count"],
        labels={col: COL_LABELS[col], cs_col: f"Average {COL_LABELS[cs_col]}", "count": "Count"},
        title=f"Average Critic Score by Top {n_cats} {COL_LABELS[col]}s",
    )

    # X-axis and layout adjustments
    fig.update_xaxes(range=[1, max_score * 1.05])
    fig.update_layout(showlegend=False)

    fig.show()

# %% [markdown]
# ##### Observations
#
# - Global sales are highly concentrated, with the same genres (Sports, Action, Shooter), platforms (PS2, X360, PS3), publishers (EA, Activision, Ubisoft), and developers (EA, Ubisoft, Rockstar Games) accounting for a disproportionate share of total sales. This reflects a strong skew toward a small number of high-performing categories.
# - Median regional sales are relatively similar across categories, with _North America_ consistently leading, followed by _PAL_ regions and _Japan_, and _Other_ regions trailing. However, this pattern may be influenced by differences in data coverage across regions.
# - Regional distributions broadly reflect global patterns, with the aforementioned categories occupying large shares across most regions. However, _Japan_ exhibits a distinct distribution, where the _Role-Playing_ genre and _Japanese_ publishers and developers account for the largest share of sales.
# - Platform distributions follow a similar pattern, though _Japan_ shows relatively higher representation of _Nintendo_ platforms and handheld consoles compared to other regions.
# - The contrast between global totals and regional shares suggests that observed global dominance is partly driven by aggregation across regions with differing distributions, rather than uniform preferences.
# - Average critic scores are relatively similar across high-coverage categories, with limited variation. This aligns with the earlier observation of weak-to-moderate correlation between critic scores and sales.

# %% [markdown]
# #### Temporal, numerical, and categorical features

# %% [markdown]
# ##### Sales over time across regions

# %%
# Plot sales over time across regions

# Calculate sum of sales across regions over time
viz_df = (
    df.group_by(pl.col("release_date").dt.year().alias("year"))
    .agg(pl.col(SALES_COLS).sum())
    .sort("year")
    .rename(COL_LABELS, strict=False)
)

# Create a line plot
fig = px.line(
    viz_df,
    x="year",
    y=[COL_LABELS[c] for c in SALES_COLS],
    line_shape="spline",
    labels={"year": "Year", "value": "Sales (Millions)", "variable": "Region"},
    title="Regional Sales Over Time",
)

fig.show()

# %%
# Plot triannually sales across regions

rd = "release_date"
rd_col = pl.col(rd)
sales_cols = pl.col(SALES_COLS)

viz_df = (
    df.filter(rd_col.is_not_null())
    .sort(rd_col)
    # Offset the window by one month and group every four months
    .group_by_dynamic(rd, every="4mo", offset="1mo")
    .agg(sales_cols.sum())
    .with_columns(rd_col.dt.month().alias("month"))
    .with_columns(
        pl.when(pl.col("month") == 2)
        .then(pl.lit("T1"))
        .when(pl.col("month") == 6)
        .then(pl.lit("T2"))
        .otherwise(pl.lit("T3"))
        .alias("tertile")
    )
    .with_columns(pl.format("{} {}", rd_col.dt.year(), pl.col("tertile")).alias("hover_label"))
    .rename(COL_LABELS, strict=False)
)

fig = px.line(
    viz_df,
    x=COL_LABELS[rd],
    y=[COL_LABELS[c] for c in SALES_COLS],
    line_shape="spline",
    labels={"value": "Sales (Millions)", "variable": "Region"},
    custom_data=["hover_label"],
    title="Triannually Regional Sales",
)

fig.update_traces(hovertemplate="%{customdata[0]}<br>Sales (Millions): %{y}<extra></extra>")

fig.show()

# %%
# Plot the correlation matrix of year, month, yearly tertiles and regionsl sales

rd = "release_date"
rd_col = pl.col(rd)
month_col = pl.col("month")

viz_df = (
    df.filter(rd_col.is_not_null())
    .select(
        # Compress sales
        pl.col(SALES_COLS).log1p(),
        rd_col.dt.year().alias("year"),
        rd_col.dt.month().alias("month"),
    )
    # Calculate tertiles
    .with_columns(
        pl.when(month_col.is_between(2, 5))
        .then(pl.lit(1))
        .when(month_col.is_between(6, 9))
        .then(pl.lit(2))
        .otherwise(pl.lit(3))
        .alias("tertile")
    )
    .eda.corr(label="column")
    .filter(pl.col("column").str.ends_with("_mil"))
    .select(~cs.ends_with("_mil"))
)

# Create a heatmap plot mapping correlation values to gradient colors
fig = px.imshow(
    viz_df.select(cs.exclude("column")),
    x=["Year", "Month", "Tertile"],
    y=SALES_COL_LABELS,
    text_auto=".1g",
    zmin=-1,
    zmax=1,
    title="Correlation Matrix: Year, Monthly, Triannually, and Regional Sales",
)

fig.update_layout(hovermode=False)

fig.show()

# %% [markdown]
# ##### Sales over time by genre, console, publisher, and developer

# %%
# Plot the rolling average of sales over time across regions by genre, console, publisher, and developer

cols = ["genre", "console", "publisher", "developer"]
sales_cols = pl.col(SALES_COLS)
rd_col = pl.col("release_date")
n_cats = 5
window = 3

for col in cols:
    # Get top catagories by region
    top_cats = (
        df.group_by(col)
        .agg(sales_cols.sum())
        .select([pl.col(col).top_k_by(c, k=n_cats).alias(c) for c in SALES_COLS])
        .select(pl.concat_arr(pl.all()).explode().alias("categories"))
        .get_column("categories")
        # Maintain order to sort legend items by volume of sales
        .unique(maintain_order=True)
        .to_list()
    )

    # Get sales over time by top categories
    viz_df = (
        df.filter(pl.col(col).is_in(top_cats), rd_col.is_not_null())
        .with_columns(rd_col.dt.year().alias("year"))
        .group_by(["year", col])
        .agg(
            [pl.col(c).sum() for c in SALES_COLS]
            + [pl.col("title").top_k_by(c, k=100).alias(f"{c}_top_titles") for c in SALES_COLS]
        )
        .sort("year")
        # Group by column and upsample to fill gaps in years
        .upsample("year", every="1i", group_by=col)
        .with_columns(
            [
                # Calculate rolling average centered at the current year
                pl.col(c).fill_null(0.0).rolling_mean(window, min_samples=1, center=True).alias(c)
                for c in SALES_COLS
            ]
            + [
                pl.format(
                    "<br>  {}",
                    pl.col(f"{c}_top_titles")
                    .list.unique(maintain_order=True)
                    .list.head(5)
                    .list.join("<br>  "),
                )
                for c in SALES_COLS
            ]
        )
    )

    # Create a subplots figure with one row per region
    fig = make_subplots(
        rows=len(SALES_COLS),
        cols=1,
        shared_xaxes=True,
        vertical_spacing=0.06,
        subplot_titles=[COL_LABELS[c] for c in SALES_COLS],
    )

    legends = set()
    labels = {"year": "Year", **COL_LABELS, **{f"{c}_top_titles": "Top Titles" for c in SALES_COLS}}

    # Create a line plot of sales across regions by categories
    for i, region in enumerate(SALES_COLS, 1):
        trace = px.line(
            viz_df,
            x="year",
            y=region,
            color=col,
            hover_data=[f"{region}_top_titles"],
            line_shape="spline",
            category_orders={col: top_cats},
            labels=labels,
        )

        # Show only the first legend item for each category
        for t in trace.data:
            if t.name in legends:
                t.showlegend = False
            else:
                legends.add(t.name)
                t.showlegend = True

            # Add trace to subplots
            fig.add_trace(t, row=i, col=1)

    # Axes and layout adjustments
    fig.update_xaxes(title_text="Year")
    fig.update_yaxes(title_text="Rolling Avg Sales (Millions)")
    fig.update_layout(
        title=f"Regional Sales Over Time by Top {len(top_cats)} {COL_LABELS[col]}s (Rolling Average)",
        height=100 + len(SALES_COLS) * 250,
    )

    fig.show()

# %%
# Animate the efficiency and share of sales of top genres over time for each region

rd_col = pl.col("release_date")
col = "genre"
n_cats = 10
window = 5

# Base data
base_df = df.filter(rd_col.is_not_null()).with_columns(rd_col.dt.year().alias("year"))
year_min, year_max = base_df["year"].min(), base_df["year"].max()
all_years = pl.int_range(year_min, year_max + 1, eager=True).alias("year").to_frame()
total_years = year_max - year_min + 1

global_mean = base_df.select(pl.col(SALES_COLS).mean())
alpha = base_df.group_by(col).len().mean()["len"] * (window / total_years)

for region in SALES_COLS:
    region_df = base_df.filter(pl.col(region).is_not_null())

    yearly_stats = (
        region_df.group_by(["year", col])
        .agg(
            pl.col(region).sum().alias("sales_sum"),
            pl.len().alias("count"),
        )
        .filter(pl.col(col).is_not_null())
    )

    top_cats = (
        yearly_stats.group_by(col)
        .agg(pl.col("sales_sum").sum())
        .top_k(n_cats, by="sales_sum")
        .get_column(col)
        .to_list()
    )

    # Full year × category grid so every frame has every category
    grid = all_years.join(pl.DataFrame({col: top_cats}), how="cross")

    viz_df = (
        grid.join(yearly_stats, on=["year", col], how="left")
        .fill_null(0)
        .sort(["year", col])
        # Calculate rolling sum per category
        .with_columns(
            pl.col("sales_sum")
            .rolling_sum(window, min_samples=1, center=True)
            .clip(lower_bound=0)
            .over(col)
            .alias("smooth_sales"),
            pl.col("count")
            .rolling_sum(window, min_samples=1, center=True)
            .clip(lower_bound=0)
            .over(col)
            .alias("smooth_count"),
        )
        # Bayesian-smoothed efficiency: shrinks toward regional mean when count is low
        .with_columns(
            pl.col("smooth_sales")
            .eda.bayesian_smooth(
                "smooth_count",
                global_mean[region],
                alpha=alpha,
                is_rate=False,  # Metric is sum, not rate
            )
            .alias("efficiency")
        )
        # Market share within each year
        .with_columns(
            (pl.col("smooth_count") / pl.col("smooth_count").sum().over("year"))
            .fill_nan(0)
            .alias("count_share"),
            (pl.col("smooth_sales") / pl.col("smooth_sales").sum().over("year"))
            .fill_nan(0)
            .alias("sales_share"),
        )
        # Short-term trend signals (3-year MA diff per category)
        .with_columns(
            pl.col("efficiency").rolling_mean(3).diff().over(col).alias("eff_trend"),
            pl.col("count_share").rolling_mean(3).diff().over(col).alias("share_trend"),
        )
        # Lifecycle phase classification
        .with_columns(
            pl.when((pl.col("eff_trend") > 0) & (pl.col("share_trend") > 0))
            .then(pl.lit("🟢 Golden Age"))  # more titles AND higher per-title sales
            .when((pl.col("eff_trend") < 0) & (pl.col("share_trend") > 0))
            .then(pl.lit("🟡 Saturated"))  # more titles but diminishing returns
            .when((pl.col("eff_trend") < 0) & (pl.col("share_trend") < 0))
            .then(pl.lit("🔴 Declining"))  # shrinking in both dimensions
            .otherwise(pl.lit("🔵 Stable / Emerging"))
            .alias("phase")
        )
    )

    # Create an animated scatter plot of the efficiency and share of sales of top genres
    fig = px.scatter(
        viz_df,
        x="count_share",
        y="efficiency",
        animation_frame="year",
        animation_group=col,
        color="phase",
        color_discrete_map={
            "🟢 Golden Age": "#2ecc71",
            "🟡 Saturated": "#f1c40f",
            "🔴 Declining": "#e74c3c",
            "🔵 Stable / Emerging": "#3498db",
        },
        text=col,
        hover_name=col,
        hover_data={
            "sales_share": ":.1%",
            "count_share": ":.1%",
            "efficiency": ":.2f",
            col: False,
        },
        size="sales_share",
        size_max=60,
        symbol=col,
        symbol_sequence=["circle"],
        category_orders={col: top_cats},
        range_x=[-0.1, viz_df["count_share"].max() * 1.25],
        range_y=[
            max(0, viz_df["efficiency"].min() * 0.9),
            viz_df["efficiency"].max() * 1.2,
        ],
        title=f"{COL_LABELS[region]}: Top {n_cats} {COL_LABELS[col]}s Lifecycle - Supply Share vs. Per-Title Efficiency (Top {n_cats})",
        labels={
            "count_share": "Supply Share (% of titles released this year)",
            "efficiency": "Avg Sales per Title (Bayesian-smoothed)",
            "sales_share": "Revenue Share",
            "phase": "Lifecycle Phase",
            "year": "Year",
            col: COL_LABELS[col],
        },
        height=580,
    )

    fig.update_traces(
        mode="markers+text",
        textfont_size=9,
        textposition="top center",
        marker=dict(sizemode="area", sizemin=8, line=dict(width=1, color="white")),
    )

    # Standardize trace marker size, name, and legend group for consistency
    def update_trace(trace):
        trace.marker.size = max(0.001, trace.marker.size)
        trace.legendgroup = trace.name
        # trace.name is "phase, category" - keep only the category part
        trace.name = trace.name.split(",")[-1].strip()

    # Update initial trace data
    for trace in fig.data:
        update_trace(trace)

    # Update per-frame trace data
    for frame in fig.frames:
        frame.layout.update(legend_title_text=COL_LABELS[col])
        for trace in frame.data:
            update_trace(trace)

    # Redraw the plot to update the legend
    if fig.layout.updatemenus:
        menu = fig.layout.updatemenus[0]

        for button in menu.buttons:
            # Update the 'redraw' arg for both 'Play' and 'Pause'
            if len(button.args) > 1:
                button.args[1]["frame"]["redraw"] = True

    # Do the same for the slider
    if fig.layout.sliders:
        for step in fig.layout.sliders[0].steps:
            step.args[1]["frame"]["redraw"] = True

    fig.update_layout(xaxis_tickformat=".0%", legend_title_text=COL_LABELS[col])

    # Set animation speed
    fig.layout.updatemenus[0].buttons[0].args[1]["frame"]["duration"] = 350
    fig.layout.updatemenus[0].buttons[0].args[1]["transition"]["duration"] = 150

    fig.show()

# %%
# Animate a simulation of the efficiency and share of sales of top genres over time for each region

rd_col = pl.col("release_date")
col = "genre"
sigma = 2.5
window = 3
alpha = 10.0
n_cats = 10

# Base data
base_df = df.filter(rd_col.is_not_null()).with_columns(rd_col.dt.year().alias("release_year"))
year_min, year_max = base_df["release_year"].min(), base_df["release_year"].max()
all_years = pl.int_range(year_min, year_max + 1, eager=True).alias("year").to_frame()

for region in SALES_COLS:
    base_df = base_df.filter(pl.col(region).is_not_null())
    # Average sales in region for smoothing
    global_mean = base_df[region].mean()

    # Gaussian year weights:
    # For each (release_year, target_year) pair, compute how much of that game's sales/presence to attribute to target_year
    # Sales: symmetric Gaussian centered at release - launch spike, symmetric decay
    # Presence: half-Gaussian (right side only) - game releases then persists, doesn't pre-exist
    norm_pdf = stats.norm(loc=0, scale=sigma).pdf
    half_norm_pdf = stats.halfnorm(loc=0, scale=sigma).pdf

    year_pairs = (
        all_years.rename({"year": "release_year"})
        .join(all_years, how="cross")  # (release_year, year)
        .with_columns((pl.col("year") - pl.col("release_year")).alias("delta"))
        .with_columns(
            pl.col("delta")
            .map_elements(lambda d: float(norm_pdf(d)), return_dtype=pl.Float64)
            .alias("sales_weight"),
            pl.col("delta")
            .map_elements(lambda d: float(half_norm_pdf(d)), return_dtype=pl.Float64)
            .alias("presence_weight"),
        )
        # Normalize weights per release_year so they sum to 1 across target years
        .with_columns(
            (pl.col("sales_weight") / pl.col("sales_weight").sum().over("release_year")).alias(
                "sales_weight_norm"
            ),
            (
                pl.col("presence_weight") / pl.col("presence_weight").sum().over("release_year")
            ).alias("presence_weight_norm"),
        )
        .filter(pl.col("delta") >= 0)  # don't attribute sales before release
    )

    # Per-release-year genre aggregates
    yearly = (
        base_df.group_by(["release_year", col])
        .agg(
            pl.col(region).sum().alias("sales_sum"),
            pl.len().alias("count"),
        )
        .filter(pl.col(col).is_not_null())
    )

    top_cats = (
        yearly.group_by(col)
        .agg(pl.col("sales_sum").sum())
        .top_k(n_cats, by="sales_sum")
        .get_column(col)
        .to_list()
    )

    # Distribute sales and presence across target years via Gaussian weights
    # Join: (release_year, genre) × (release_year -> year weights) -> (year, genre, weighted contribution)
    distributed = (
        yearly.filter(pl.col(col).is_in(top_cats))
        .join(year_pairs, on="release_year", how="left")
        .with_columns(
            (pl.col("sales_sum") * pl.col("sales_weight_norm")).alias("sales_contrib"),
            (pl.col("count") * pl.col("presence_weight_norm")).alias("presence_contrib"),
        )
        .group_by(["year", col])
        .agg(
            pl.col("sales_contrib").sum().alias("sales_dist"),
            pl.col("presence_contrib").sum().alias("presence_dist"),
        )
    )

    # Full grid + cumulative position + smoothed trend signal
    grid = all_years.join(pl.DataFrame({col: top_cats}), how="cross")

    viz_df = (
        grid.join(distributed, on=["year", col], how="left")
        .fill_null(strategy="zero")
        .sort([col, "year"])
        # Cumulative position where this genre has accumulated to
        .with_columns(
            pl.col("sales_dist").cum_sum().over(col).alias("sales_cum"),
            pl.col("presence_dist").cum_sum().over(col).alias("presence_cum"),
        )
        # Bayesian-smoothed cumulative efficiency
        .with_columns(
            pl.col("sales_cum")
            .eda.bayesian_smooth(
                pl.col("presence_cum"),
                global_mean,
                alpha=alpha,
                is_rate=False,  # Metric is cumulative sum, not rate
            )
            .alias("efficiency")
            # ((pl.col("sales_cum") + alpha * global_mean) / (pl.col("presence_cum") + alpha)).alias(
            #     "efficiency"
            # )
        )
        # Cumulative market share - position in the plot
        .with_columns(
            (pl.col("presence_cum") / pl.col("presence_cum").sum().over("year"))
            .fill_nan(0)
            .alias("count_share"),
            (pl.col("sales_cum") / pl.col("sales_cum").sum().over("year"))
            .fill_nan(0)
            .alias("sales_share"),
        )
        # Yearly (non-cumulative) shares for trend signal - smoothed to reduce noise
        .with_columns(
            (pl.col("sales_dist") / pl.col("sales_dist").sum().over("year"))
            .fill_nan(0)
            .alias("sales_share_yearly"),
            (pl.col("presence_dist") / pl.col("presence_dist").sum().over("year"))
            .fill_nan(0)
            .alias("count_share_yearly"),
        )
        .with_columns(
            pl.col("efficiency")
            .diff()
            .rolling_mean(window, min_samples=1)
            .over(col)
            .alias("eff_trend"),
            pl.col("count_share_yearly")
            .rolling_mean(window, min_samples=1)
            .diff()
            .over(col)
            .alias("share_trend"),
        )
        # Phase: based on smoothed yearly momentum, not cumulative diff
        .with_columns(
            pl.when((pl.col("eff_trend") > 0) & (pl.col("share_trend") > 0))
            .then(pl.lit("🟢 Golden Age"))
            .when((pl.col("eff_trend") < 0) & (pl.col("share_trend") > 0))
            .then(pl.lit("🟡 Saturated"))
            .when((pl.col("eff_trend") < 0) & (pl.col("share_trend") < 0))
            .then(pl.lit("🔴 Declining"))
            .otherwise(pl.lit("🔵 Stable / Emerging"))
            .alias("phase")
        )
    )

    # Create an animated scatter plot
    fig = px.scatter(
        viz_df,
        x="count_share",
        y="efficiency",
        animation_frame="year",
        animation_group=col,
        color="phase",
        color_discrete_map={
            "🟢 Golden Age": "#2ecc71",
            "🟡 Saturated": "#f1c40f",
            "🔴 Declining": "#e74c3c",
            "🔵 Stable / Emerging": "#3498db",
        },
        text=col,
        hover_name=col,
        hover_data={
            "sales_share": ":.1%",
            "count_share": ":.1%",
            "efficiency": ":.2f",
            "sales_share_yearly": ":.1%",
            col: False,
        },
        size="sales_share",
        size_max=60,
        symbol=col,
        symbol_sequence=["circle"],
        category_orders={col: top_cats},
        range_x=[-0.1, viz_df["count_share"].max() * 1.25],
        range_y=[
            max(0, viz_df["efficiency"].min() * 0.9),
            viz_df["efficiency"].max() * 1.2,
        ],
        title=f"{COL_LABELS[region]}: Top {n_cats} {COL_LABELS[col]}s Lifecycle - Cumulative Position vs. Efficiency (σ={sigma}y)",
        labels={
            "count_share": "Cumulative Presence Share",
            "efficiency": "Avg Sales per Title (Bayesian-smoothed)",
            "sales_share": "Cumulative Revenue Share",
            "sales_share_yearly": "Yearly Revenue Share",
            "phase": "Lifecycle Phase",
            "year": "Year",
            col: COL_LABELS[col],
        },
        height=580,
    )

    fig.update_traces(
        mode="markers+text",
        textfont_size=9,
        textposition="top center",
        marker=dict(sizemode="area", sizemin=8, line=dict(width=1, color="white")),
    )

    # Standardize trace marker size, name, and legend group for consistency
    def update_trace(trace):
        trace.marker.size = max(0.001, trace.marker.size)
        trace.legendgroup = trace.name
        # trace.name is "phase, category" - keep only the category part
        trace.name = trace.name.split(",")[-1].strip()

    # Update initial trace data
    for trace in fig.data:
        update_trace(trace)

    # Update per-frame trace data
    for frame in fig.frames:
        frame.layout.update(legend_title_text=COL_LABELS[col])
        for trace in frame.data:
            update_trace(trace)

    # Redraw the plot to update the legend
    if fig.layout.updatemenus:
        menu = fig.layout.updatemenus[0]

        for button in menu.buttons:
            # Update the 'redraw' arg for both 'Play' and 'Pause'
            if len(button.args) > 1:
                button.args[1]["frame"]["redraw"] = True

    # Do the same for the slider
    if fig.layout.sliders:
        for step in fig.layout.sliders[0].steps:
            step.args[1]["frame"]["redraw"] = True

    fig.update_layout(xaxis_tickformat=".0%", legend_title_text=COL_LABELS[col])

    # Set animation speed
    fig.layout.updatemenus[0].buttons[0].args[1]["frame"]["duration"] = 350
    fig.layout.updatemenus[0].buttons[0].args[1]["transition"]["duration"] = 150

    fig.show()

# %% [markdown]
# ##### Observations
#
# - Despite the spikes in sales volume in Q4 of the year, aggregated sales values don't appear to reflect a correlation between the quarters of the year.
# - While a small number of genres, platforms, publishers, and developers dominate global sales, their prominence is not constant over time. Certain categories exhibit periods of growth and decline, suggesting that aggregate dominance is shaped by temporal concentration rather than uniform performance.
# - Region-specific categories, such as _Role-Playing_ and _Bandai Namco_ in _Japan_, maintain a more consistent presence over time, reinforcing the earlier observation of regional specialization.
# - Consoles follow a generational lifecycle, where the introduction of new platforms signals the gradual phasing out of older hardware.

# %% [markdown]
# ### Summary and conclusions
#
# - Sales are highly concentrated, with a small number of genres, platforms, publishers, and developers accounting for a disproportionate share of total sales.
# - While global patterns suggest dominance of genres such as Sports, Action, and Shooter, regional distributions reveal meaningful variation, particularly in Japan where Role-Playing titles occupy a larger share.
# - Temporal analysis shows that these patterns are not static, with category dominance shifting over time, indicating that aggregate trends are influenced by temporal concentration.
# - Critic scores exhibit limited variation and weak association with sales, suggesting they are not a primary driver of commercial success within this dataset.
# - Overall, observed global dominance reflects aggregation across heterogeneous regional and temporal patterns, rather than uniform behavior across the dataset.

# %% [markdown]
# ## Part 4: Feature engineering, modeling, and forecasting
#
# This part if about transforming features to improve their usefulness in modeling, and forecasting revenues. Due to the sparsity and fragmentation of the dataset, as well as the established constraints, modeling will be focused on data within a temporal window.

# %% [markdown]
# ### Feature selection and engineering strategy
#
# When engineering features for modeling, one main concern is data leakage - exposing or encoding information that can help create unwanted bias. Another concern is selecting features which are representative of the predefined problem, and expose signals that describe the target variables. But before that, the dataset should be split to evaluate how predictors generalize to unseen data, and the target variables need to be transformed to abide by the predefined constraints.

# %% [markdown]
# #### Split the dataset

# %%
# Allocate a portion of the dataset for training, and the rest for validation

MIN_YEAR, MAX_YEAR = 2000, 2020
SPLIT_YEAR = MAX_YEAR - 3
DATASET_CUTOFF = date(MAX_YEAR, 12, 31)

# Focus on years with highest sales availability
model_df = df.with_columns(pl.col("release_date").dt.year().alias("release_year")).filter(
    pl.col("release_year").is_between(MIN_YEAR, MAX_YEAR)
)

# Temporal split
train_df = model_df.filter(pl.col("release_year") < SPLIT_YEAR)
val_df = model_df.filter(pl.col("release_year") >= SPLIT_YEAR)

# Verify
print("Training min release year:", train_df["release_year"].min())
print("Training max release year:", train_df["release_year"].max())
print("Validation min release year:", val_df["release_year"].min())
print("Validation max release year:", val_df["release_year"].max())

# %% [markdown]
# #### Encode target variables

# %%
# Plot the Quantile-Quantile distributions for target variables in different scales and ranges


def get_qq_coords(df: pl.DataFrame, columns: list[str]) -> pl.DataFrame:
    """
    Compute Q-Q coordinates for columns.
    Returns a long-format DataFrame.
    """
    return (
        df.select(columns)
        # Unpivot to convert from wide to long-format
        .unpivot(on=columns, variable_name="variable", value_name="observed")
        .drop_nulls()
        .sort(["variable", "observed"])
        .with_columns(
            # Count how many non-null points exist for each variable group
            pl.len().over("variable").alias("n_i"),
            # Determine the local rank index (1 to n) for each point in each variable group
            pl.int_range(1, pl.len() + 1).over("variable").alias("rank"),
        )
        .with_columns(
            # Calculate the explicit probability position for each point
            ((pl.col("rank") - 0.5) / pl.col("n_i")).alias("prob")
        )
        # Map the probabilities to Theoretical Standard Normal Quantiles
        .with_columns(
            pl.col("prob").map_batches(lambda s: stats.norm.ppf(s.to_numpy())).alias("theoretical")
        )
        .select(["variable", "theoretical", "observed"])
    )


sales_cols = pl.col(SALES_COL_LABELS)
transforms = [" Linear", " Log", " Log p95 (Truncated)", " Log p95 (Winsorized)"]

# Transform regional sales to log scale using different strategies
base_df = (
    train_df.select(pl.col(SALES_COLS))
    .rename(COL_LABELS, strict=False)
    .select(
        sales_cols.name.suffix(" Linear"),
        sales_cols.log().name.suffix(" Log"),
        pl.when(sales_cols < sales_cols.quantile(0.95))
        .then(sales_cols)
        .log()
        .name.suffix(" Log p95 (Truncated)"),
        pl.when(sales_cols < sales_cols.quantile(0.95))
        .then(sales_cols)
        .otherwise(sales_cols.quantile(0.95))
        .log()
        .name.suffix(" Log p95 (Winsorized)"),
    )
)

# Generate Q-Q coordinates from transformed sales
viz_df = get_qq_coords(base_df, base_df.columns)

# Category order for each transformation in each region
category_orders = [f"{c}{s}" for c in SALES_COL_LABELS for s in transforms]

# Create a faceted scatter plot figure for linear and transformed sales
fig = px.scatter(
    viz_df,
    x="theoretical",
    y="observed",
    facet_col="variable",
    facet_col_wrap=len(transforms),
    facet_row_spacing=0.04,
    facet_col_spacing=0.04,
    category_orders={"variable": category_orders},
    title="Regional Sales: Q-Q Diagnostic",
    labels={"theoretical": "Theoretical Quantiles", "observed": "Sample Quantiles"},
    render_mode="webgl",
)

# Decouple axes and display ticks and labels for each subplot
fig.update_xaxes(matches=None, showticklabels=True)
fig.update_yaxes(matches=None, showticklabels=True)

# Remove "variable=" from hover text
fig.for_each_trace(lambda t: t.update(hovertemplate=t.hovertemplate.replace("variable=", "")))

# Compute stats
stats_df = (
    viz_df.group_by("variable")
    .agg(
        pl.col("observed").mean().alias("mean"),
        pl.col("observed").std().alias("std"),
        pl.col("observed").skew().alias("skewness"),
        pl.col("observed").kurtosis().alias("kurtosis"),
        pl.col("theoretical").min().alias("min_x"),
        pl.col("theoretical").max().alias("max_x"),
    )
    # Cast to an Enum with an ordinal order matching category order
    .with_columns(pl.col("variable").cast(pl.Enum(category_orders)))
    .sort("variable")
)

# Add normal distribution reference lines
for trace, row in zip(fig.data, stats_df.iter_rows(named=True)):
    min_x, max_x = row["min_x"], row["max_x"]
    min_y = (row["std"] * min_x) + row["mean"]
    max_y = (row["std"] * max_x) + row["mean"]

    # Get annotation index from axis identifier
    match = re.search(r"\d+", trace.xaxis)
    anno_idx = int(match.group()) - 1 if match else 0
    fig.layout.annotations[
        anno_idx
    ].text = f"{row['variable']}, S={row['skewness']:.2f}, K={row['kurtosis']:.2f}"

    # Add a shape for reference line and layer above markers
    fig.add_shape(
        type="line",
        x0=min_x,
        y0=min_y,
        x1=max_x,
        y1=max_y,
        line=dict(color="red", dash="dash", width=4),
        xref=trace.xaxis,
        yref=trace.yaxis,
        layer="above",
    )

fig.update_layout(height=len(SALES_COLS) * 300)
fig.show()

# %%
# Transform target variables

# Fit transformation with the train set
sales_p95 = train_df.select(pl.col(SALES_COLS).quantile(0.95))

train_df = train_df.with_columns(
    [pl.when(pl.col(c) < sales_p95[c]).then(pl.col(c)).log() for c in SALES_COLS]
)

val_df = val_df.with_columns(
    [pl.when(pl.col(c) < sales_p95[c]).then(pl.col(c)).log() for c in SALES_COLS]
)

# Verify
train_df.select(SALES_COLS).eda.describe()
val_df.select(SALES_COLS).eda.describe()

# %% [markdown]
# #### Select and transform predictors

# %%
# Select and transform predictors based on potential signal strengths within the problem constraints

EXCLUDE_CONSOLES = {
    "PSN", "XBL", "VC", "DSiW", "WW",    # digital storefronts
    "PC",                                # biased sample - low availability
    "All", "Series",                     # aggregators
    "And", "iOS", "Linux", "OSX",        # near-zero availability
}  # fmt: skip

CONSOLES_KEEP = {
    # Tier 1 - reliable signal (relatively high availability)
    "DS", "PS2", "PS3", "Wii", "X360", "PSP",
    "PS4", "XB", "GBA", "PSV", "GC", "3DS", "XOne",
    # Tier 2 - lower reliability, kept with awareness
    "PS", "NS", "WiiU",
}  # fmt: skip

# Target variable is total sales for now
TARGET = TOTAL_SALES_COL

train_df = train_df.filter(
    pl.col(TARGET).is_not_null(), ~pl.col("console").is_in(EXCLUDE_CONSOLES)
).with_columns(pl.col("release_date").dt.month().alias("release_month"))
val_df = val_df.filter(
    pl.col(TARGET).is_not_null(), ~pl.col("console").is_in(EXCLUDE_CONSOLES)
).with_columns(pl.col("release_date").dt.month().alias("release_month"))


def _publisher_tier(n: int) -> str:
    if n >= 200:
        return "major"
    if n >= 50:
        return "mid"
    if n >= 10:
        return "small"
    return "micro"


# Aggregate and bucket publisher from training window only
publisher_tier_df = (
    train_df.group_by("publisher")
    .len()
    .with_columns(
        pl.col("len").map_elements(_publisher_tier, return_dtype=pl.String).alias("publisher_tier")
    )
    .select("publisher", "publisher_tier")
)

# Genre lag and global fallback average from training window only
genre_lag_df = (
    train_df.group_by(["genre", "release_year"])
    .agg(pl.col(TARGET).mean().alias("_genre_year_avg"))
    .sort(["genre", "release_year"])
    .with_columns(pl.col("_genre_year_avg").shift(1).over("genre").alias("genre_avg_sales_lag1"))
    .select("genre", "release_year", "genre_avg_sales_lag1")
)

global_mean_log = train_df[TARGET].mean()


# Feature engineering - applied identically to training and validation sets
def build_features(
    df: pl.DataFrame,
    publisher_tier_df: pl.DataFrame,
    genre_lag_df: pl.DataFrame,
    global_mean_log: float,
) -> tuple[np.ndarray, np.ndarray]:

    result = (
        df.with_columns(pl.col(TARGET).alias("target"))
        # Console bucketing
        .with_columns(
            pl.when(pl.col("console").is_in(CONSOLES_KEEP))
            .then(pl.col("console"))
            .otherwise(pl.lit("other"))
            .alias("console_bucketed")
        )
        # Publisher tier - left join applies training-fitted tiers
        # unseen publishers in val (null) filled as "micro"
        .join(publisher_tier_df, on="publisher", how="left")
        .with_columns(pl.col("publisher_tier").fill_null("micro"))
        # Genre lag - unseen genre/year combos in validation filled with global average
        .join(genre_lag_df, on=["genre", "release_year"], how="left")
        .with_columns(pl.col("genre_avg_sales_lag1").fill_null(global_mean_log))
        # Holiday season
        .with_columns(
            pl.when(pl.col("release_month").is_between(2, 9))
            .then(pl.lit(0))
            .otherwise(pl.lit(1))
            .cast(pl.Int8)
            .alias("is_holiday_season")
        )
        .with_columns(
            ((pl.lit(DATASET_CUTOFF) - pl.col("release_date")).dt.total_days() / 365.25)
            .clip(lower_bound=0)
            .alias("years_on_market")
        )
        .select(
            "target",
            "genre",
            "console_bucketed",
            "publisher_tier",
            # "release_tertile",
            "is_holiday_season",
            "years_on_market",
            "genre_avg_sales_lag1",
        )
        .drop_nulls(subset=["target"])
    )

    X = result.drop("target")
    y = result["target"].to_numpy()
    return X.to_numpy(), y, X


X_train, y_train, X_train_df = build_features(
    train_df, publisher_tier_df, genre_lag_df, global_mean_log
)
X_val, y_val, X_val_df = build_features(val_df, publisher_tier_df, genre_lag_df, global_mean_log)


print(f"Global mean log sales (train): {global_mean_log:.3f}")
print(f"\nTrain      {X_train.shape} ({MIN_YEAR}-{SPLIT_YEAR - 1})")
print(f"Validation  {X_val.shape} ({SPLIT_YEAR}-{MAX_YEAR})")
print(f"\nTarget mean - train: {y_train.mean():.3f}  validation: {y_val.mean():.3f}")
print(f"Target std  - train: {y_train.std():.3f}   validation: {y_val.std():.3f}")

# %% [markdown]
# #### Recap
#
# - Temporal range for modeling is between 2000 and 2020 to focus on recent years with available sales. The last four years are allocated to the validation set.
# - Target variables are truncated to their respective 95th percentile and log scaled.
# - Consoles are filtered to focus on those with higher availability and reliability.
# - All features, except for `years_on_market`, are fitted on the training set only.
# - `years_on_market` is engineered in accordance with the structure of the dataset, which contains pre-aggregated sales values recorded at unknown date.

# %% [markdown]
# ### Modeling and evaluation

# %% [markdown]
# #### Dummy regression

# %%
# A baseline evaluation model to which other models will be compared
# The Dummy Regressor is configured to always predict the average value


def evaluate(
    model,
    X_train: np.ndarray,
    y_train: np.ndarray,
    X_val: np.ndarray,
    y_val: np.ndarray,
    label: str,
) -> dict:
    """
    Evaluate a fitted model in both log and original scale.
    Returns a results dict for later comparison across models.
    """
    y_train_pred = model.predict(X_train)
    y_val_pred = model.predict(X_val)

    # Smearing correction: exp(ŷ + σ²/2)
    # σ² estimated from training residuals
    residual_var = np.var(y_train - y_train_pred)
    correction = np.exp(0.5 * residual_var)

    # Back-transform: log -> original scale (millions)
    y_train_orig = np.exp(y_train)
    y_val_orig = np.exp(y_val)
    y_train_pred_orig = np.exp(y_train_pred) * correction
    y_val_pred_orig = np.exp(y_val_pred) * correction

    results = {
        "model": label,
        # Log scale
        "rmse_train_log": root_mean_squared_error(y_train, y_train_pred),
        "rmse_val_log": root_mean_squared_error(y_val, y_val_pred),
        # Original scale
        "rmse_train_mil": root_mean_squared_error(y_train_orig, y_train_pred_orig),
        "rmse_val_mil": root_mean_squared_error(y_val_orig, y_val_pred_orig),
        # Percentage error
        "mape_train": mean_absolute_percentage_error(y_train_orig, y_train_pred_orig),
        "mape_val": mean_absolute_percentage_error(y_val_orig, y_val_pred_orig),
        # Smearing correction factor - useful diagnostic
        "smearing_factor": correction,
    }

    print(f"\n{'─' * 40}")
    print(f"  {label}")
    print(f"{'─' * 40}")
    print(
        f"  RMSE  log  - train: {results['rmse_train_log']:.4f}  validation: {results['rmse_val_log']:.4f}"
    )
    print(
        f"  RMSE  mil  - train: {results['rmse_train_mil']:.4f}  validation: {results['rmse_val_mil']:.4f}"
    )
    print(
        f"  MAPE       - train: {results['mape_train']:.4f}  validation: {results['mape_val']:.4f}"
    )
    print(f"  Smearing correction: {correction:.4f}")

    return results


# Fit and evaluate
dummy = DummyRegressor(strategy="mean")
dummy.fit(X_train, y_train)

results = []
results.append(evaluate(dummy, X_train, y_train, X_val, y_val, "Dummy (mean)"))

# %% [markdown]
# #### Linear regression

# %%
# Evaluate and compare a Linear Regressor to the baseline regressor

# Use the same random seed for reproducibility
SEED = 42

# Column index mapping to map Numpy array columns to DataFrame columns
COL_IDX = {name: i for i, name in enumerate(X_train_df.columns)}

unordered_categorical_idx = [COL_IDX["genre"], COL_IDX["console_bucketed"]]
ordered_categorical_idx = [COL_IDX["publisher_tier"]]
numerical_idx = [
    COL_IDX["is_holiday_season"],
    COL_IDX["years_on_market"],
    COL_IDX["genre_avg_sales_lag1"],
]

unordered_categorical_features = [
    "genre",
    "console_bucketed",
]
ordered_categorical_features = [
    "publisher_tier",
]
numerical_features = [
    "is_holiday_season",
    "years_on_market",
    "genre_avg_sales_lag1",
]

preprocessor = ColumnTransformer(
    transformers=[
        (
            "cat",
            OneHotEncoder(handle_unknown="ignore", sparse_output=False),
            unordered_categorical_idx + ordered_categorical_idx,
        ),
        (
            "num",
            StandardScaler(),
            numerical_idx,
        ),
    ]
)

ridge = Pipeline(
    [
        ("preprocessor", preprocessor),
        ("model", Ridge(alpha=1.0)),
    ]
)

ridge.fit(X_train, y_train)
results.append(evaluate(ridge, X_train, y_train, X_val, y_val, "Ridge (alpha=1.0)"))

# %% [markdown]
# #### Tree regression

# %%
# Tree models handle categoricals differently - ordinal encoding is
# sufficient since the tree doesn't assume ordinality, it just splits
# on values. OHE would unnecessarily widen the feature space and slow
# tree growth without adding information.

# Explicit tier ordering: micro=0, small=1, mid=2, major=3
# This gives the tree a meaningful numeric scale to split on
tier_encoder = OrdinalEncoder(
    categories=[["micro", "small", "mid", "major"]],
    handle_unknown="use_encoded_value",
    unknown_value=-1,
)

tree_preprocessor = ColumnTransformer(
    transformers=[
        (
            "cat_unordered",
            OrdinalEncoder(handle_unknown="use_encoded_value", unknown_value=-1),
            unordered_categorical_idx,
        ),
        (
            "cat_ordered",
            tier_encoder,
            ordered_categorical_idx,
        ),
        (
            "num",
            "passthrough",
            numerical_idx,
        ),
    ]
)

# Shallow decision tree - interpretability first
shallow_tree = Pipeline(
    [
        ("preprocessor", tree_preprocessor),
        ("model", DecisionTreeRegressor(max_depth=4, min_samples_leaf=50, random_state=SEED)),
    ]
)


shallow_tree.fit(X_train, y_train)
results.append(evaluate(shallow_tree, X_train, y_train, X_val, y_val, "Decision Tree (depth=4)"))

# Print the tree structure - useful for sanity checking which features
# the model considers most informative at the top splits
feature_names = unordered_categorical_features + ordered_categorical_features + numerical_features
print("\nTree structure:")
print(
    export_text(
        shallow_tree.named_steps["model"],
        feature_names=feature_names,
        max_depth=3,  # print top 3 levels only for readability
    )
)

# Random Forest
rf = Pipeline(
    [
        ("preprocessor", tree_preprocessor),
        (
            "model",
            RandomForestRegressor(
                n_estimators=200,
                max_depth=8,
                min_samples_leaf=20,
                max_features="sqrt",
                random_state=SEED,
                n_jobs=-1,
            ),
        ),
    ]
)

rf.fit(X_train, y_train)
results.append(evaluate(rf, X_train, y_train, X_val, y_val, "Random Forest (depth=8)"))

# Feature importance
importances = pl.DataFrame(
    {
        "feature": feature_names,
        "importance": rf.named_steps["model"].feature_importances_,
    }
).sort("importance", descending=True)
print("\nRandom Forest feature importances:")
print(importances)

# Feature importance by impact of each permutation
perm = permutation_importance(
    rf,
    X_val,
    y_val,
    n_repeats=20,
    random_state=SEED,
    n_jobs=-1,
    scoring="neg_root_mean_squared_error",
)

perm_df = pl.DataFrame(
    {
        "feature": feature_names,
        "importance": perm.importances_mean,
        "std": perm.importances_std,
    }
).sort("importance", descending=True)
print("\nPermutation importances (validation set):")
print(perm_df)

# Print a summary table of all results
print()
summary_df = pl.DataFrame(results)
print(summary_df)

# %%
# XGBoost Regressor

categorical_features = unordered_categorical_features + ordered_categorical_features

X_train_xgb = X_train_df.with_columns(pl.col(categorical_features).cast(pl.Categorical))
X_val_xgb = X_val_df.with_columns(pl.col(categorical_features).cast(pl.Categorical))

# Baseline XGBoost - conservative hyperparameters
# Depth 4 mirrors the shallow tree baseline for comparability
xgb_model = XGBRegressor(
    n_estimators=500,
    max_depth=4,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    min_child_weight=20,  # mirrors min_samples_leaf=20 in Random Forest
    reg_lambda=1.0,  # L2 regularisation
    reg_alpha=0.0,  # L1 regularisation
    enable_categorical=True,
    tree_method="hist",  # required for categorical support
    eval_metric="rmse",
    early_stopping_rounds=30,
    random_state=SEED,
    n_jobs=-1,
)

xgb_model.fit(
    X_train_xgb,
    y_train,
    eval_set=[(X_train_xgb, y_train), (X_val_xgb, y_val)],
    verbose=50,
)

results.append(evaluate(xgb_model, X_train_xgb, y_train, X_val_xgb, y_val, "XGBoost (depth=4)"))

# Feature importance: gain-based, analogous to Gini for trees
xgb_importance = pl.DataFrame(
    {
        "feature": list(xgb_model.feature_names_in_),
        "importance": list(xgb_model.feature_importances_),
    }
).sort("importance", descending=True)
print("\nXGBoost feature importances (gain):")
print(xgb_importance)
print()

summary_df = pl.DataFrame(results)
print(summary_df)

# %% [markdown]
# #### Model tuning

# %%
# Run the XGBoost Regressor using different hyperparameter values

param_grid = {
    "max_depth": [3, 4, 6],
    "learning_rate": [0.01, 0.05, 0.1],
    "min_child_weight": [10, 20, 50],
}

best_score = np.inf
best_params = {}

for params in ParameterGrid(param_grid):
    model = XGBRegressor(
        n_estimators=1000,
        subsample=0.8,
        colsample_bytree=0.8,
        reg_lambda=1.0,
        enable_categorical=True,
        tree_method="hist",
        eval_metric="rmse",
        early_stopping_rounds=30,
        random_state=SEED,
        n_jobs=-1,
        **params,
    )
    model.fit(
        X_train_xgb,
        y_train,
        eval_set=[(X_val_xgb, y_val)],
        verbose=False,
    )
    score = root_mean_squared_error(y_val, model.predict(X_val_xgb))
    if score < best_score:
        best_score = score
        best_params = params
        best_n = model.best_iteration

print(f"Best val RMSE log: {best_score:.4f}")
print(f"Best params: {best_params}")
print(f"Best n_estimators: {best_n}")

# Re-evaluate the model using the found hyperparameter values
xgb_tuned = XGBRegressor(
    n_estimators=best_n,
    max_depth=3,
    learning_rate=0.05,
    min_child_weight=20,
    subsample=0.8,
    colsample_bytree=0.8,
    reg_lambda=1.0,
    enable_categorical=True,
    tree_method="hist",
    random_state=SEED,
    n_jobs=-1,
)

xgb_tuned.fit(
    X_train_xgb,
    y_train,
    eval_set=[(X_val_xgb, y_val)],
    verbose=False,
)

results.append(evaluate(xgb_tuned, X_train_xgb, y_train, X_val_xgb, y_val, "XGBoost (tuned)"))

print()
summary_df = pl.DataFrame(results).sort("rmse_val_log")
print(summary_df)

# %% [markdown]
# #### Regional model evaluation

# %%
# Define a function for training and evaluating regional models


@dataclass
class RegionalModel:
    region: str
    model: XGBRegressor
    p95: float
    global_mean_log: float
    train_size: int
    val_size: int
    val_rmse_log: float
    residual_var: float  # for smearing correction


def train_regional_model(
    sales_col: str,
    train_df: pl.DataFrame,
    val_df: pl.DataFrame,
    publisher_tier_df: pl.DataFrame,
    genre_lag_df: pl.DataFrame,
) -> RegionalModel:
    """
    Train a regional XGBoost model.
    Statistics (p95, genre lag, global mean) are fitted on regional
    training data independently to avoid cross-regional leakage.
    """
    # Fit regional statistics on training data only
    regional_p95 = train_df[sales_col].quantile(0.95)

    regional_genre_lag = (
        train_df.filter(pl.col(sales_col).is_not_null())
        .with_columns(
            pl.when(pl.col(sales_col) < regional_p95)
            .then(pl.col(sales_col))
            .log()
            .alias("_log_sales")
        )
        .group_by(["genre", "release_year"])
        .agg(pl.col("_log_sales").mean().alias("_genre_year_avg"))
        .sort(["genre", "release_year"])
        .with_columns(
            pl.col("_genre_year_avg").shift(1).over("genre").alias("genre_avg_sales_lag1")
        )
        .select("genre", "release_year", "genre_avg_sales_lag1")
    )

    regional_global_mean = (
        train_df.filter(pl.col(sales_col).is_not_null())
        .with_columns(
            pl.when(pl.col(sales_col) < regional_p95)
            .then(pl.col(sales_col))
            .log()
            .alias("_log_sales")
        )["_log_sales"]
        .mean()
    )

    # Build regional feature matrices
    def build_regional_features(
        df: pl.DataFrame,
        target_col: str,
    ) -> tuple[pl.DataFrame, np.ndarray]:
        result = (
            df.filter(pl.col(target_col).is_not_null())
            .with_columns(
                pl.when(pl.col(target_col) < regional_p95)
                .then(pl.col(target_col))
                .log()
                .alias("target")
            )
            .with_columns(
                pl.when(pl.col("console").is_in(CONSOLES_KEEP))
                .then(pl.col("console"))
                .otherwise(pl.lit("other"))
                .alias("console_bucketed")
            )
            .join(publisher_tier_df, on="publisher", how="left")
            .with_columns(pl.col("publisher_tier").fill_null("micro"))
            .join(regional_genre_lag, on=["genre", "release_year"], how="left")
            .with_columns(pl.col("genre_avg_sales_lag1").fill_null(regional_global_mean))
            .with_columns(
                pl.when(pl.col("release_month").is_in([10, 11, 12, 1]))
                .then(pl.lit(True))
                .otherwise(pl.lit(False))
                .cast(pl.Int8)
                .alias("is_holiday_season")
            )
            .with_columns(
                ((pl.lit(DATASET_CUTOFF) - pl.col("release_date")).dt.total_days() / 365.25)
                .clip(lower_bound=0)
                .alias("years_on_market")
            )
            .select(
                "target",
                *unordered_categorical_features,
                *ordered_categorical_features,
                *numerical_features,
            )
            .drop_nulls(subset=["target"])
        )

        X = result.drop("target").with_columns(pl.col(categorical_features).cast(pl.Categorical))
        y = result["target"].to_numpy()
        return X, y

    X_tr, y_tr = build_regional_features(train_df, sales_col)
    X_vl, y_vl = build_regional_features(val_df, sales_col)

    model = XGBRegressor(
        n_estimators=best_n,
        max_depth=3,
        learning_rate=0.1,
        min_child_weight=20,
        subsample=0.8,
        colsample_bytree=0.8,
        reg_lambda=1.0,
        enable_categorical=True,
        tree_method="hist",
        random_state=SEED,
        n_jobs=-1,
    )
    model.fit(X_tr, y_tr)

    val_rmse = root_mean_squared_error(y_vl, model.predict(X_vl))
    residual_var = float(np.var(y_tr - model.predict(X_tr)))

    return RegionalModel(
        region=COL_LABELS[sales_col],
        model=model,
        p95=regional_p95,
        global_mean_log=regional_global_mean,
        train_size=len(y_tr),
        val_size=len(y_vl),
        val_rmse_log=val_rmse,
        residual_var=residual_var,
    )

# %%
# Train and evaluate all regional models

base_df = df.filter(pl.col("release_date").dt.year().is_between(MIN_YEAR, MAX_YEAR)).with_columns(
    pl.col("release_date").dt.year().alias("release_year"),
    pl.col("release_date").dt.month().alias("release_month"),
)

train_df = base_df.filter(pl.col("release_year") < SPLIT_YEAR)
val_df = base_df.filter(pl.col("release_year") >= SPLIT_YEAR)

# Train all regional models
regional_models: dict[str, RegionalModel] = {}

for region in SALES_COLS:
    regional_models[region] = train_regional_model(
        region,
        train_df,
        val_df,
        publisher_tier_df,
        genre_lag_df,
    )

# Regional model quality summary
print("\nRegional model summary:")
print(
    pl.DataFrame(
        [
            {
                "region": rm.region,
                "train_size": rm.train_size,
                "val_size": rm.val_size,
                "val_rmse_log": rm.val_rmse_log,
                "p95_mil": rm.p95,
            }
            for rm in regional_models.values()
        ]
    ).sort("val_rmse_log")
)

# %% [markdown]
# #### Observations
#
# - Dummy Regressor's validation RMSE in log space (1.52) is higher than train std (1.29). Because the average is computed using titles from train that have had more time to accumulate sales, the model is optimistic in its predictions. Every model will inherit this bias (reporting lag bias). RMSE in millions is lower on validation (0.26) than train (0.29). This is the right-skew effect. Titles in the validation set are more recent and small-selling (reporting lag), so absolute errors in millions are smaller even though relative errors are larger.
# - Ridge validation RMSE log dropped from 1.52 in baseline to 1.24, which confirms the features carry real linear signal. The train / validation gap is modest (1.11 / 1.24), suggesting its regularization is doing its job and the model isn't over-fitting the categorical dummies.
# - Decision Tree and Random Forest RMSE train log values (1.15 and 1.08, respectively) are on par with Ridge's (1.11), however they generalize worse to the validation set. This suggests they are penalized by the reporting lag bias more than Ridge.
# - In contrast, XGBoost models (baseline and tuned) generalize better to the validation set, but only marginally.
# - With an RMSE validation log difference of 0.02, Ridge is a robust and simpler fallback with no tuning required.
# - Regional validation RMSE log values range from 0.82 in _Other_ to 1.23 in _PAL_. The discrepancies can be attributed to the difference in their distributions and 95th percentile values.

# %% [markdown]
# ### Forecasting and inference

# %%
# Retrain on full 2000-2020 window


# No validation set metrics to keep track of
@dataclass
class RegionalModelFull:
    region: str
    model: XGBRegressor
    p95: float
    global_mean_log: float
    train_size: int
    residual_var: float


full_df = df.filter(
    pl.col(TOTAL_SALES_COL).is_not_null(),
    pl.col("release_date").is_not_null(),
    pl.col("release_date").dt.year().is_between(MIN_YEAR, MAX_YEAR),
    ~pl.col("console").is_in(EXCLUDE_CONSOLES),
).with_columns(
    pl.col("release_date").dt.year().alias("release_year"),
    pl.col("release_date").dt.month().alias("release_month"),
)

# Refit all statistics on full window
full_p95 = full_df[TOTAL_SALES_COL].quantile(0.95)

full_publisher_tier_df = (
    full_df.group_by("publisher")
    .len()
    .with_columns(
        pl.col("len").map_elements(_publisher_tier, return_dtype=pl.String).alias("publisher_tier")
    )
    .select("publisher", "publisher_tier")
)

full_genre_lag_df = (
    full_df.with_columns(
        pl.when(pl.col(TOTAL_SALES_COL) < full_p95)
        .then(pl.col(TOTAL_SALES_COL))
        .log()
        .alias("_log_sales")
    )
    .group_by(["genre", "release_year"])
    .agg(pl.col("_log_sales").mean().alias("_genre_year_avg"))
    .sort(["genre", "release_year"])
    .with_columns(pl.col("_genre_year_avg").shift(1).over("genre").alias("genre_avg_sales_lag1"))
    .select("genre", "release_year", "genre_avg_sales_lag1")
)

full_global_mean = (
    full_df.with_columns(
        pl.when(pl.col(TOTAL_SALES_COL) < full_p95)
        .then(pl.col(TOTAL_SALES_COL))
        .log()
        .alias("_log_sales")
    )
    .get_column("_log_sales")
    .mean()
)

print(f"Full window p95:         {full_p95:.4f}M")
print(f"Full window global mean: {full_global_mean:.4f}")
print(f"Full window rows:        {full_df.height}")


# Retrain regional models on full window
def train_regional_model_full(
    sales_col: str,
) -> RegionalModelFull:
    """
    Retrain a regional model on the full 2000-2019 window.
    No val set - best_n from tuning is fixed.
    residual_var estimated from training residuals.
    """
    regional_p95 = full_df[sales_col].drop_nulls().quantile(0.95)

    regional_genre_lag = (
        full_df.filter(pl.col(sales_col).is_not_null())
        .with_columns(
            pl.when(pl.col(sales_col) < regional_p95)
            .then(pl.col(sales_col))
            .log()
            .alias("_log_sales")
        )
        .group_by(["genre", "release_year"])
        .agg(pl.col("_log_sales").mean().alias("_genre_year_avg"))
        .sort(["genre", "release_year"])
        .with_columns(
            pl.col("_genre_year_avg").shift(1).over("genre").alias("genre_avg_sales_lag1")
        )
        .select("genre", "release_year", "genre_avg_sales_lag1")
    )

    regional_global_mean = (
        full_df.filter(pl.col(sales_col).is_not_null())
        .with_columns(
            pl.when(pl.col(sales_col) < regional_p95)
            .then(pl.col(sales_col))
            .log()
            .alias("_log_sales")
        )["_log_sales"]
        .mean()
    )

    def build_full_features(
        target_col: str,
    ) -> tuple[pl.DataFrame, np.ndarray]:
        result = (
            full_df.filter(pl.col(target_col).is_not_null())
            .with_columns(
                pl.when(pl.col(target_col) < regional_p95)
                .then(pl.col(target_col))
                .log()
                .alias("target")
            )
            .with_columns(
                pl.when(pl.col("console").is_in(CONSOLES_KEEP))
                .then(pl.col("console"))
                .otherwise(pl.lit("other"))
                .alias("console_bucketed")
            )
            .join(full_publisher_tier_df, on="publisher", how="left")
            .with_columns(pl.col("publisher_tier").fill_null("micro"))
            .join(regional_genre_lag, on=["genre", "release_year"], how="left")
            .with_columns(pl.col("genre_avg_sales_lag1").fill_null(regional_global_mean))
            .with_columns(
                pl.when(pl.col("release_month").is_in([10, 11, 12, 1]))
                .then(pl.lit(True))
                .otherwise(pl.lit(False))
                .cast(pl.Int8)
                .alias("is_holiday_season")
            )
            .with_columns(
                ((pl.lit(DATASET_CUTOFF) - pl.col("release_date")).dt.total_days() / 365.25)
                .clip(lower_bound=0)
                .alias("years_on_market")
            )
            .select(
                "target",
                *unordered_categorical_features,
                *ordered_categorical_features,
                *numerical_features,
            )
            .drop_nulls(subset=["target"])
        )

        X = result.drop("target").with_columns(pl.col(categorical_features).cast(pl.Categorical))
        y = result["target"].to_numpy()
        return X, y

    X, y = build_full_features(sales_col)

    region = COL_LABELS[sales_col]
    print(f"\n{region.upper():>14} - full train: {len(y):>5}  p95: {regional_p95:.3f}M")

    model = XGBRegressor(
        n_estimators=best_n,  # fixed from tuning - no early stopping
        max_depth=3,
        learning_rate=0.05,
        min_child_weight=20,
        subsample=0.8,
        colsample_bytree=0.8,
        reg_lambda=1.0,
        enable_categorical=True,
        tree_method="hist",
        random_state=SEED,
        n_jobs=-1,
    )
    model.fit(X, y)

    residual_var = float(np.var(y - model.predict(X)))

    return RegionalModelFull(
        region=region,
        model=model,
        p95=regional_p95,
        global_mean_log=regional_global_mean,
        train_size=len(y),
        residual_var=residual_var,
    )


# Replace regional_models with full-window versions
regional_models = {}
for region in SALES_COLS:
    regional_models[region] = train_regional_model_full(region)

# %%
# Define the forecast functions for estimating expected regional revenues

# Uncertainty constant - applied uniformly across all regions
# Acknowledges unknown generalisation error of full-window model
INTERVAL_EXPANSION = 1.3


@dataclass
class ForecastResult:
    region: str
    genre: str
    console: str
    years_on_market: float
    point_estimate: float
    lower_bound: float
    upper_bound: float
    log_prediction: float
    residual_std: float
    caveats: list[str]

    def __str__(self) -> str:
        lines = [
            f"\n{'─' * 50}",
            f"  Forecast - {self.region.upper()} - {self.genre} / {self.console}",
            f"{'─' * 50}",
            f"  Years on market:   {self.years_on_market:.1f}",
            f"  Point estimate:    {self.point_estimate:.3f}M",
            f"  Interval (1.3σ):   {self.lower_bound:.3f}M - {self.upper_bound:.3f}M",
            f"  Residual std:      {self.residual_std:.4f}",
        ]
        if self.caveats:
            lines.append("  Caveats:")
            for c in self.caveats:
                lines.append(f"    • {c}")
        lines.append(f"{'─' * 50}")
        return "\n".join(lines)


def forecast(
    genre: str,
    console: str,
    release_date: date,
    region: str,
    years_on_market: float = 5.0,
    publisher_tier: str = "micro",
) -> ForecastResult:
    """
    Forecast cumulative sales for an indie studio title.

    Parameters
    ----------
    genre           : game genre (must match training categories)
    console         : target console (bucketed internally if not in CONSOLES_KEEP)
    release_date    : intended release date (used to derive genre lag)
    region          : region column name
    years_on_market : forecast horizon in years (default 5 - matches project brief)
    publisher_tier  : fixed at "micro" for indie studio; exposed for scenario analysis
    """
    rm = regional_models[region]
    caveats = []

    # Resolve console
    console_bucketed = console if console in CONSOLES_KEEP else "other"
    if console_bucketed == "other":
        caveats.append(
            f"Console '{console}' not in training set - bucketed as 'other'. "
            f"Forecast generalises from low-frequency platforms."
        )

    # Genre lag: use last available year before forecast date
    release_year = release_date.year
    available_years = (
        full_genre_lag_df.filter(pl.col("genre") == genre)
        .filter(pl.col("release_year") < release_year)
        .sort("release_year", descending=True)
    )

    if available_years.height > 0:
        genre_lag = available_years["genre_avg_sales_lag1"][0]
        lag_year = available_years["release_year"][0]
        if lag_year < release_year - 2:
            caveats.append(
                f"Genre lag uses data from {lag_year} - "
                f"{release_year - lag_year} years before forecast date. "
                f"Genre popularity signal may be stale."
            )
    else:
        genre_lag = rm.global_mean_log
        caveats.append(f"No genre lag available for '{genre}' - using global mean fallback.")

    # Holiday season flag
    is_holiday = int(release_date.month in {10, 11, 12, 1})

    # Assemble input row
    input_df = pl.DataFrame(
        {
            "genre": [genre],
            "console_bucketed": [console_bucketed],
            "publisher_tier": [publisher_tier],
            "is_holiday_season": [is_holiday],
            "years_on_market": [years_on_market],
            "genre_avg_sales_lag1": [genre_lag],
        },
        schema={
            "genre": pl.Categorical,
            "console_bucketed": pl.Categorical,
            "publisher_tier": pl.Categorical,
            "is_holiday_season": pl.Int8,
            "years_on_market": pl.Float64,
            "genre_avg_sales_lag1": pl.Float64,
        },
    )

    # Predict
    log_pred = float(rm.model.predict(input_df)[0])
    residual_std = float(np.sqrt(rm.residual_var))

    # Smearing correction: exp(ŷ + σ²/2)
    correction = np.exp(0.5 * rm.residual_var)
    point_est = np.exp(log_pred) * correction

    # Prediction interval: ±1.3 * residual_std in log space
    # Conservative expansion acknowledges unknown generalisation error
    # of full-window model (no holdout set available)
    lower = np.exp(log_pred - residual_std * INTERVAL_EXPANSION) * correction
    upper = np.exp(log_pred + residual_std * INTERVAL_EXPANSION) * correction

    # Clip to [0, p95]
    point_est = float(np.clip(point_est, 0, rm.p95))
    lower = float(np.clip(lower, 0, rm.p95))
    upper = float(np.clip(upper, 0, rm.p95))

    # Fixed caveats for indie context
    if publisher_tier == "micro":
        caveats.append(
            "Forecast conditioned on micro publisher tier. "
            "Predictions reflect indie market segment, not overall genre average."
        )
    if years_on_market > 10:
        caveats.append(
            f"years_on_market={years_on_market:.0f} extrapolates beyond most "
            f"training observations. Long-horizon forecasts carry higher uncertainty."
        )

    return ForecastResult(
        region=region,
        genre=genre,
        console=console,
        years_on_market=years_on_market,
        point_estimate=point_est,
        lower_bound=lower,
        upper_bound=upper,
        log_prediction=log_pred,
        residual_std=residual_std,
        caveats=caveats,
    )


def forecast_grid(
    region: str,
    years_on_market: float = 5.0,
    release_date: date = date(2025, 1, 1),
    consoles: list[str] | None = None,
    genres: list[str] | None = None,
) -> pl.DataFrame:
    """
    Generate a forecast grid across all genre x console combinations.
    Returns a ranked DataFrame of point estimates with intervals.
    """
    if consoles is None:
        consoles = sorted(CONSOLES_KEEP)
    if genres is None:
        genres = full_df["genre"].unique().sort().to_list()

    rows = []
    for genre in genres:
        for console in consoles:
            result = forecast(
                genre=genre,
                console=console,
                release_date=release_date,
                region=region,
                years_on_market=years_on_market,
            )
            rows.append(
                {
                    "genre": genre,
                    "console": console,
                    "point_est_mil": result.point_estimate,
                    "lower_mil": result.lower_bound,
                    "upper_mil": result.upper_bound,
                    "log_pred": result.log_prediction,
                }
            )

    return (
        pl.DataFrame(rows)
        .sort("point_est_mil", descending=True)
        .with_columns(
            pl.col("point_est_mil", "lower_mil", "upper_mil").round(4),
            pl.col("log_pred").round(4),
        )
    )

# %%
# Forecast expected regional revenues for all genre x console combinations
# five years past the last year in the dataset. The forecasted revenues also assume
# five years on the market, therefore the expected revenues are ten years past the
# last year in the dataset.

FORECAST_WINDOW = 5
DATASET_MAX_YEAR = df["release_date"].dt.year().max()
FORECAST_YEAR = DATASET_MAX_YEAR + FORECAST_WINDOW

# Release date is five years past the last year in the dataset, and in the holiday season
RELEASE_DATE = date(FORECAST_YEAR, 12, 25)

print("Release date:", RELEASE_DATE)
print("Forecast window:", FORECAST_WINDOW)

# Top 20 genre x console combinations globally
grid_total = forecast_grid(
    region=TOTAL_SALES_COL, years_on_market=FORECAST_WINDOW, release_date=RELEASE_DATE
)

print(
    f"\nTop 20 genre x console combinations ({COL_LABELS[TOTAL_SALES_COL]}, {FORECAST_WINDOW}-year horizon):"
)
with pl.Config(set_tbl_rows=20):
    print(grid_total)

# Regional comparison for top 10 total combinations
top_10 = grid_total.head(10).select("genre", "console")

print("\nTop 10 combinations - regional breakdown:")
regional_rows = []
for row in top_10.iter_rows(named=True):
    for region in SALES_COLS:
        result = forecast(
            genre=row["genre"],
            console=row["console"],
            release_date=RELEASE_DATE,
            region=region,
            years_on_market=FORECAST_WINDOW,
        )
        regional_rows.append(
            {
                "genre": row["genre"],
                "console": row["console"],
                "region": region,
                "point_est_mil": round(result.point_estimate, 4),
            }
        )

regional_grid = (
    pl.DataFrame(regional_rows)
    .pivot(on="region", index=["genre", "console"], values="point_est_mil")
    .sort(TOTAL_SALES_COL, descending=True)
)

with pl.Config(set_tbl_width_chars=120):
    print(regional_grid)

# %% [markdown]
# ### Summary and findings
#
# **What the model produces**
# A cross-sectional XGBoost regressor trained on 2000-2020 game sales data, producing 5-year cumulative revenue estimates for a small indie studio releasing a new IP. Five independent regional models (Total, North America, Japan, PAL, Other) share the same architecture and feature set, differing only in their training populations and p95 ceilings.
# Predictions are made in log space and back-transformed with a smearing correction (exp(ŷ + σ²/2)) to account for Jensen's inequality. Intervals are set at ±1.3σ in log space - conservative by design, acknowledging the absence of a holdout set for the full-window models.
#
# **Key findings**
# Sandbox genre on modern home consoles dominate the top combinations - Sandbox/XOne, Sandbox/PS4, and Sandbox/NS lead the global grid. This reflects the Minecraft-era surge observed in the dataset and should be interpreted with caution: the genre may be considerably more saturated than the training window suggests.
# Regional models are sharper than the total model - _Japan_ (validation RMSE log 0.92) and _Other_ (0.81) outperform _Total_ (1.21) and _PAL_ (1.20) because smaller, more homogeneous markets have lower irreducible variance. The studio should weight _Japan_ and _Other_ regional forecasts more confidently than _Total_ or _PAL_.
# Regional forecasts are not additive - _North America_ + _Japan_ + _PAL_ + _Other_ will not equal _Total_ because the five models are trained independently on different subsets. Use _Total_ for headline figures and regional models for relative market sizing only.
# _Publisher_ is the dominant signal (40% Gini, 14% permutation importance on validation) but collapses in every indie studio forecast. The model is effectively predicting using a low-tier publisher subpopulation - a narrow but realistic distribution for the studio's planning purposes.
#
# **Known limitations and caveats**
# **Genre lag is stale** - it is anchored to 2020 data for any forecast scenario. Genre popularity cycles (battle royale, survival, cozy games) that emerged or peaked post-2020 are invisible to the model. Treat genre rankings as indicative of long-run structural demand rather than current market trends.
# **Modern consoles (PS5, XS) are treated generically** - neither platform has meaningful sales data in the training window. Given more data, they could easily make it to the top of the grid. Console lifecycle plays a key role in generated revenues, and by the time the studio will have released a title, they may have already become legacy.
# **Intervals are wide by design** - a typical forecast carries much wider margins. This reflects genuine irreducible uncertainty in individual game sales. The studio should plan around the lower bound as a conservative case and treat the point estimate as a central scenario, not a target.
# **The model is a market-conditioned prior, not a title-specific prediction** - without critic scores, franchise history, or marketing spend, the model cannot distinguish between two Action-Adventure games on the same console released in the same month. It answers "what does a low-tier publisher indie title in this genre/console/era typically sell?" - which is the right question for strategic planning but not for title-by-title forecasting.
